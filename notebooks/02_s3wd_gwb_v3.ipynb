# %% [markdown]
# # 02 · S3WD v02 主线：参考元组 + 相似度 + 漂移闭环
#
# 本 Notebook 演示 S3WD v02 流程：利用 Reference Tuple（参考元组）/混合相似度/批级阈值小网格，结合漂移分级响应（S1/S2/S3）。
# 运行前请确认 `configs/s3wd_airline_v02.yaml` 已更新至 v02 键位，并准备好 Airlines 数据。

# %%
import os
from pathlib import Path
import sys
import logging

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from IPython.display import display

# 中文字体配置
plt.rcParams['font.sans-serif'] = ['SimHei', 'Microsoft YaHei', 'Arial Unicode MS']
plt.rcParams['axes.unicode_minus'] = False

# 工程根目录自动探测：当前目录或上级目录中包含 s3wdlib
PROJECT_ROOT = Path.cwd()
if not (PROJECT_ROOT / 's3wdlib').exists() and (PROJECT_ROOT.parent / 's3wdlib').exists():
    PROJECT_ROOT = PROJECT_ROOT.parent
if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

logging.basicConfig(level=logging.INFO, format='[%(levelname)s] %(message)s')

print("【步骤0】环境信息：", {
    "python": sys.version.split()[0],
    "cwd": os.getcwd(),
    "project_root": str(PROJECT_ROOT),
})
# Out:
# 【步骤0】环境信息： {'python': '3.11.5', 'cwd': 'e:\\yan\\组\\三支决策\\机器学习\\C三支决策与不平衡数据集分类\\S3WD实验\\notebooks', 'project_root': 'e:\\yan\\组\\三支决策\\机器学习\\C三支决策与不平衡数据集分类\\S3WD实验'}

# %%
# 读取 v02 配置并展示关键信息
from s3wdlib.config_loader import load_yaml_cfg, show_cfg

CONFIG_PATH = PROJECT_ROOT / "configs" / "s3wd_airline_v02.yaml"

cfg = load_yaml_cfg(str(CONFIG_PATH))
print("【步骤1】配置文件已加载：", CONFIG_PATH)
show_cfg(cfg)
# Out:
# [INFO] Loading faiss.
# [INFO] Successfully loaded faiss.
# 【步骤1】配置文件已加载： e:\yan\组\三支决策\机器学习\C三支决策与不平衡数据集分类\S3WD实验\configs\s3wd_airline_v02.yaml
# 【配置快照】
# - DATA: {'data_dir': '../data', 'data_file': 'airlines_train_regression_1000000.arff', 'continuous_label': 'DepDelay', 'threshold': 15, 'threshold_op': '>', 'test_size': 0.3, 'val_size': 0.3, 'random_state': 42, 'start_year': 1987}
# - LEVEL: {'level_pcts': [0.6, 0.8, 1.0], 'ranker': 'mi'}
# - KWB: {'k': 6, 'metric': 'euclidean', 'eps': 1e-06, 'use_faiss': True, 'faiss_gpu': True}
# - GWB: {'k': 10, 'metric': 'euclidean', 'eps': 1e-06, 'mode': 'epanechnikov', 'bandwidth': 0.72, 'bandwidth_scale': 1.05, 'use_faiss': True, 'faiss_gpu': True, 'categorical_features': ['Origin', 'Dest'], 'category_penalty': 0.3}
# - S3WD: {'c1': 0.37, 'c2': 0.63, 'xi_min': 0.1, 'theta_pos': 0.9, 'theta_neg': 0.1, 'sigma': 3.0, 'regret_mode': 'utility', 'penalty_large': 1000000.0, 'gamma_last': True, 'gap': 0.02}
# - PSO: {'particles': 20, 'iters': 20, 'w_max': 0.9, 'w_min': 0.4, 'c1': 2.8, 'c2': 1.3, 'seed': 42, 'use_gpu': True}
# - BUCKET: {'keys': ['UniqueCarrier', 'Origin', 'Dest', 'dep_hour'], 'min_bucket': 500, 'backoff': [['UniqueCarrier', 'Origin', 'Dest'], ['Origin', 'Dest'], ['Origin']]}
# - REF_TUPLE: {'topk_per_class': 256, 'pos_quantile': 0.7, 'keep_history_ratio': 0.3, 'use_gwb_weight': True}
# - SIMILARITY: {'kernel': 'rbf', 'sigma': 0.5, 'cat_weights': {'carrier': 0.4, 'origin': 0.2, 'dest': 0.2, 'dow': 0.1, 'month': 0.1}, 'combine': 'product', 'mix_alpha': 0.7}
# - MEASURE: {'objective': 'expected_cost', 'costs': {'c_fn': 1.0, 'c_fp': 0.4, 'c_bnd': 0.2}, 'grid': {'alpha': [0.55, 0.9, 0.02], 'beta': [0.05, 0.45, 0.02]}, 'constraints': {'keep_gap': 0.05, 'min_pos_coverage': 0.02, 'bnd_cap': 0.35}}
# - SMOOTH: {'ema_alpha': 0.6, 'step_cap': {'alpha': 0.08, 'beta': 0.08}}
# - SWITCH: {'enable_ref_tuple': True, 'enable_pso': False}
# - DRIFT: {'method': 'kswin', 'window_size': 512, 'stat_size': 128, 'psi_thresholds': {'warn': 0.1, 'alert': 0.25}, 'tv_thresholds': {'warn': 0.1, 'alert': 0.2}, 'posrate_shift': {'warn': 0.05, 'alert': 0.1}, 'perf_drop': {'warn': 0.1, 'alert': 0.2}, 'debounce_windows': 3, 'actions': {'S1': {'sigma_factor': [1.2, 0.85], 'redo_threshold': True}, 'S2': {'rebuild_ref_tuple': True, 'keep_history_ratio': 0.3, 'redo_threshold': True}, 'S3': {'rebuild_ref_tuple': True, 'rebuild_gwb_index': True, 'keep_history_ratio': 0.3, 'tighten': {'keep_gap': 0.08, 'bnd_cap': 0.25, 'step_cap': 0.05}, 'cooldown_windows': 3}}}
# - FLOW: {'warmup_windows': 6, 'recent_windows': 3, 'time_decay': 0.18, 'seasonal_neighbor': 0.75, 'seasonal_other': 0.45, 'weight_max': 2.5, 'history_cap': 12}
# - TIME: {'split': 'year_month'}
# - VAL: {'inline_delay': True}

# %%
# 仅运行「流式 v02 主线」，不再单独做静态基线实验
from s3wdlib.v02_flow import run_streaming_flow

print("\n【步骤2】开始运行流式前滚 v02（只保留动态部分）...")
results = run_streaming_flow(str(CONFIG_PATH))

trace_df = results.get("threshold_trace")
metrics_df = results.get("window_metrics")
yearly_df = results.get("metrics_by_year") or results.get("yearly_metrics")

print("\n【步骤3】流式前滚完成。窗口级指标预览：")
if metrics_df is not None:
    display(metrics_df.head())

print("\n【步骤4】按年份汇总指标：")
if yearly_df is not None:
    display(yearly_df)

# 简单画一张按年份的 F1 / BAC 曲线，便于快速观察动态方案效果
if yearly_df is not None:
    fig, ax = plt.subplots(figsize=(10, 5))
    if "F1" in yearly_df.columns:
        ax.plot(yearly_df.index, yearly_df["F1"], marker="o", label="F1")
    if "BAC" in yearly_df.columns:
        ax.plot(yearly_df.index, yearly_df["BAC"], marker="o", label="BAC")
    ax.set_xlabel("year")
    ax.set_ylabel("score")
    ax.set_title("流式 v02 · 按年份 F1/BAC")
    ax.legend()
    plt.tight_layout()
    plt.show()
# Out:
# [INFO] 【验证阶段】VAL.inline_delay=true → 当前月评估仅使用延迟到达的标注。
# [INFO] 【验证阶段】VAL.inline_delay=true → 当前月评估仅使用延迟到达的标注。
# 【步骤2】开始运行流式前滚 v02（只保留动态部分）...
# 【配置快照】
# - DATA: {'data_dir': '../data', 'data_file': 'airlines_train_regression_1000000.arff', 'continuous_label': 'DepDelay', 'threshold': 15, 'threshold_op': '>', 'test_size': 0.3, 'val_size': 0.3, 'random_state': 42, 'start_year': 1987}
# - LEVEL: {'level_pcts': [0.6, 0.8, 1.0], 'ranker': 'mi'}
# - KWB: {'k': 6, 'metric': 'euclidean', 'eps': 1e-06, 'use_faiss': True, 'faiss_gpu': True}
# - GWB: {'k': 10, 'metric': 'euclidean', 'eps': 1e-06, 'mode': 'epanechnikov', 'bandwidth': 0.72, 'bandwidth_scale': 1.05, 'use_faiss': True, 'faiss_gpu': True, 'categorical_features': ['Origin', 'Dest'], 'category_penalty': 0.3}
# - S3WD: {'c1': 0.37, 'c2': 0.63, 'xi_min': 0.1, 'theta_pos': 0.9, 'theta_neg': 0.1, 'sigma': 3.0, 'regret_mode': 'utility', 'penalty_large': 1000000.0, 'gamma_last': True, 'gap': 0.02}
# - PSO: {'particles': 20, 'iters': 20, 'w_max': 0.9, 'w_min': 0.4, 'c1': 2.8, 'c2': 1.3, 'seed': 42, 'use_gpu': True}
# - BUCKET: {'keys': ['UniqueCarrier', 'Origin', 'Dest', 'dep_hour'], 'min_bucket': 500, 'backoff': [['UniqueCarrier', 'Origin', 'Dest'], ['Origin', 'Dest'], ['Origin']]}
# - REF_TUPLE: {'topk_per_class': 256, 'pos_quantile': 0.7, 'keep_history_ratio': 0.3, 'use_gwb_weight': True}
# - SIMILARITY: {'kernel': 'rbf', 'sigma': 0.5, 'cat_weights': {'carrier': 0.4, 'origin': 0.2, 'dest': 0.2, 'dow': 0.1, 'month': 0.1}, 'combine': 'product', 'mix_alpha': 0.7}
# - MEASURE: {'objective': 'expected_cost', 'costs': {'c_fn': 1.0, 'c_fp': 0.4, 'c_bnd': 0.2}, 'grid': {'alpha': [0.55, 0.9, 0.02], 'beta': [0.05, 0.45, 0.02]}, 'constraints': {'keep_gap': 0.05, 'min_pos_coverage': 0.02, 'bnd_cap': 0.35}}
# - SMOOTH: {'ema_alpha': 0.6, 'step_cap': {'alpha': 0.08, 'beta': 0.08}}
# - SWITCH: {'enable_ref_tuple': True, 'enable_pso': False}
# - DRIFT: {'method': 'kswin', 'window_size': 512, 'stat_size': 128, 'psi_thresholds': {'warn': 0.1, 'alert': 0.25}, 'tv_thresholds': {'warn': 0.1, 'alert': 0.2}, 'posrate_shift': {'warn': 0.05, 'alert': 0.1}, 'perf_drop': {'warn': 0.1, 'alert': 0.2}, 'debounce_windows': 3, 'actions': {'S1': {'sigma_factor': [1.2, 0.85], 'redo_threshold': True}, 'S2': {'rebuild_ref_tuple': True, 'keep_history_ratio': 0.3, 'redo_threshold': True}, 'S3': {'rebuild_ref_tuple': True, 'rebuild_gwb_index': True, 'keep_history_ratio': 0.3, 'tighten': {'keep_gap': 0.08, 'bnd_cap': 0.25, 'step_cap': 0.05}, 'cooldown_windows': 3}}}
# - FLOW: {'warmup_windows': 6, 'recent_windows': 3, 'time_decay': 0.18, 'seasonal_neighbor': 0.75, 'seasonal_other': 0.45, 'weight_max': 2.5, 'history_cap': 12}
# - TIME: {'split': 'year_month'}
# - VAL: {'inline_delay': True}
# 【数据加载完毕】样本数=1000000，特征数=9，正类比例=0.1559
# [INFO] 【初始化】warmup(月)=['0.10', '0.11', '0.12']，stream(月)=['1.01', '1.02', '1.03', '1.04', '1.05', '1.06', '1.07', '1.08', '1.09', '1.10', '1.11', '1.12', '2.01', '2.02', '2.03', '2.04', '2.05', '2.06', '2.07', '2.08', '2.09', '2.10', '2.11', '2.12', '3.01', '3.02', '3.03', '3.04', '3.05', '3.06', '3.07', '3.08', '3.09', '3.10', '3.11', '3.12', '4.01', '4.02', '4.03', '4.04', '4.05', '4.06', '4.07', '4.08', '4.09', '4.10', '4.11', '4.12', '5.01', '5.02', '5.03', '5.04', '5.05', '5.06', '5.07', '5.08', '5.09', '5.10', '5.11', '5.12', '6.01', '6.02', '6.03', '6.04', '6.05', '6.06', '6.07', '6.08', '6.09', '6.10', '6.11', '6.12', '7.01', '7.02', '7.03', '7.04', '7.05', '7.06', '7.07', '7.08', '7.09', '7.10', '7.11', '7.12', '8.01', '8.02', '8.03', '8.04', '8.05', '8.06', '8.07', '8.08', '8.09', '8.10', '8.11', '8.12', '9.01', '9.02', '9.03', '9.04', '9.05', '9.06', '9.07', '9.08', '9.09', '9.10', '9.11', '9.12', '10.01', '10.02', '10.03', '10.04', '10.05', '10.06', '10.07', '10.08', '10.09', '10.10', '10.11', '10.12', '11.01', '11.02', '11.03', '11.04', '11.05', '11.06', '11.07', '11.08', '11.09', '11.10', '11.11', '11.12', '12.01', '12.02', '12.03', '12.04', '12.05', '12.06', '12.07', '12.08', '12.09', '12.10', '12.11', '12.12', '13.01', '13.02', '13.03', '13.04', '13.05', '13.06', '13.07', '13.08', '13.09', '13.10', '13.11', '13.12', '14.01', '14.02', '14.03', '14.04', '14.05', '14.06', '14.07', '14.08', '14.09', '14.10', '14.11', '14.12', '15.01', '15.02', '15.03', '15.04', '15.05', '15.06', '15.07', '15.08', '15.09', '15.10', '15.11', '15.12', '16.01', '16.02', '16.03', '16.04', '16.05', '16.06', '16.07', '16.08', '16.09', '16.10', '16.11', '16.12', '17.01', '17.02', '17.03', '17.04', '17.05', '17.06', '17.07', '17.08', '17.09', '17.10', '17.11', '17.12', '18.01', '18.02', '18.03', '18.04', '18.05', '18.06', '18.07', '18.08', '18.09', '18.10', '18.11', '18.12', '19.01', '19.02', '19.03', '19.04', '19.05', '19.06', '19.07', '19.08', '19.09', '19.10', '19.11', '19.12', '20.01', '20.02', '20.03', '20.04', '20.05', '20.06', '20.07', '20.08', '20.09', '20.10', '20.11', '20.12', '21.01', '21.02', '21.03', '21.04', '21.05', '21.06', '21.07', '21.08', '21.09', '21.10', '21.11', '21.12', '22.01', '22.02', '22.03', '22.04', '22.05', '22.06', '22.07', '22.08', '22.09', '22.10', '22.11', '22.12', '23.01', '23.02', '23.03', '23.04', '23.05', '23.06', '23.07', '23.08', '23.09', '23.10', '23.11', '23.12', '24.01', '24.02', '24.03', '24.04', '24.05', '24.06', '24.07', '24.08', '24.09', '24.10', '24.11', '24.12', '25.01', '25.02', '25.03', '25.04', '25.05', '25.06', '25.07', '25.08', '25.09', '25.10', '25.11', '25.12', '26.01', '26.02', '26.03', '26.04', '26.05', '26.06', '26.07']，总窗口=310
# [INFO] 【初始化】warmup(月)=['0.10', '0.11', '0.12']，stream(月)=['1.01', '1.02', '1.03', '1.04', '1.05', '1.06', '1.07', '1.08', '1.09', '1.10', '1.11', '1.12', '2.01', '2.02', '2.03', '2.04', '2.05', '2.06', '2.07', '2.08', '2.09', '2.10', '2.11', '2.12', '3.01', '3.02', '3.03', '3.04', '3.05', '3.06', '3.07', '3.08', '3.09', '3.10', '3.11', '3.12', '4.01', '4.02', '4.03', '4.04', '4.05', '4.06', '4.07', '4.08', '4.09', '4.10', '4.11', '4.12', '5.01', '5.02', '5.03', '5.04', '5.05', '5.06', '5.07', '5.08', '5.09', '5.10', '5.11', '5.12', '6.01', '6.02', '6.03', '6.04', '6.05', '6.06', '6.07', '6.08', '6.09', '6.10', '6.11', '6.12', '7.01', '7.02', '7.03', '7.04', '7.05', '7.06', '7.07', '7.08', '7.09', '7.10', '7.11', '7.12', '8.01', '8.02', '8.03', '8.04', '8.05', '8.06', '8.07', '8.08', '8.09', '8.10', '8.11', '8.12', '9.01', '9.02', '9.03', '9.04', '9.05', '9.06', '9.07', '9.08', '9.09', '9.10', '9.11', '9.12', '10.01', '10.02', '10.03', '10.04', '10.05', '10.06', '10.07', '10.08', '10.09', '10.10', '10.11', '10.12', '11.01', '11.02', '11.03', '11.04', '11.05', '11.06', '11.07', '11.08', '11.09', '11.10', '11.11', '11.12', '12.01', '12.02', '12.03', '12.04', '12.05', '12.06', '12.07', '12.08', '12.09', '12.10', '12.11', '12.12', '13.01', '13.02', '13.03', '13.04', '13.05', '13.06', '13.07', '13.08', '13.09', '13.10', '13.11', '13.12', '14.01', '14.02', '14.03', '14.04', '14.05', '14.06', '14.07', '14.08', '14.09', '14.10', '14.11', '14.12', '15.01', '15.02', '15.03', '15.04', '15.05', '15.06', '15.07', '15.08', '15.09', '15.10', '15.11', '15.12', '16.01', '16.02', '16.03', '16.04', '16.05', '16.06', '16.07', '16.08', '16.09', '16.10', '16.11', '16.12', '17.01', '17.02', '17.03', '17.04', '17.05', '17.06', '17.07', '17.08', '17.09', '17.10', '17.11', '17.12', '18.01', '18.02', '18.03', '18.04', '18.05', '18.06', '18.07', '18.08', '18.09', '18.10', '18.11', '18.12', '19.01', '19.02', '19.03', '19.04', '19.05', '19.06', '19.07', '19.08', '19.09', '19.10', '19.11', '19.12', '20.01', '20.02', '20.03', '20.04', '20.05', '20.06', '20.07', '20.08', '20.09', '20.10', '20.11', '20.12', '21.01', '21.02', '21.03', '21.04', '21.05', '21.06', '21.07', '21.08', '21.09', '21.10', '21.11', '21.12', '22.01', '22.02', '22.03', '22.04', '22.05', '22.06', '22.07', '22.08', '22.09', '22.10', '22.11', '22.12', '23.01', '23.02', '23.03', '23.04', '23.05', '23.06', '23.07', '23.08', '23.09', '23.10', '23.11', '23.12', '24.01', '24.02', '24.03', '24.04', '24.05', '24.06', '24.07', '24.08', '24.09', '24.10', '24.11', '24.12', '25.01', '25.02', '25.03', '25.04', '25.05', '25.06', '25.07', '25.08', '25.09', '25.10', '25.11', '25.12', '26.01', '26.02', '26.03', '26.04', '26.05', '26.06', '26.07']，总窗口=310
# [INFO] 【年度样本量】{1987: 8777, 1988: 34232, 1989: 33206, 1990: 34973, 1991: 33822, 1992: 33694, 1993: 33469, 1994: 34363, 1995: 35145, 1996: 35073, 1997: 35264, 1998: 35278, 1999: 35530, 2000: 36947, 2001: 38456, 2002: 35028, 2003: 42994, 2004: 46414, 2005: 46656, 2006: 47205, 2007: 48442, 2008: 45928, 2009: 42612, 2010: 42255, 2011: 39755, 2012: 40239, 2013: 24243}
# [INFO] 【年度样本量】{1987: 8777, 1988: 34232, 1989: 33206, 1990: 34973, 1991: 33822, 1992: 33694, 1993: 33469, 1994: 34363, 1995: 35145, 1996: 35073, 1997: 35264, 1998: 35278, 1999: 35530, 2000: 36947, 2001: 38456, 2002: 35028, 2003: 42994, 2004: 46414, 2005: 46656, 2006: 47205, 2007: 48442, 2008: 45928, 2009: 42612, 2010: 42255, 2011: 39755, 2012: 40239, 2013: 24243}
# [INFO] 【窗口计划】年度顺序=['1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995', '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013']
# [INFO] 【窗口计划】年度顺序=['1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995', '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013']
# [INFO] 【窗口计划】warmup(年)=['1987']，stream(年)=['1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995', '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013']
# [INFO] 【窗口计划】warmup(年)=['1987']，stream(年)=['1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995', '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013']
# [INFO] 【warmup】将处理 3 个 warmup 窗口（year-month）。
# [INFO] 【warmup】将处理 3 个 warmup 窗口（year-month）。
# [INFO] 【warmup进度】1/3 (33.3%)，当前窗口=0.10，累计样本=3040，用时≈0.1s
# [INFO] 【warmup进度】1/3 (33.3%)，当前窗口=0.10，累计样本=3040，用时≈0.1s
# [INFO] 【warmup进度】3/3 (100.0%)，当前窗口=0.12，累计样本=8777，用时≈0.2s
# [INFO] 【warmup进度】3/3 (100.0%)，当前窗口=0.12，累计样本=8777，用时≈0.2s
# [INFO] 【参考库】year-month=1.01；同月历史窗口=无（年份=无，样本=0）；邻近窗口=0.10、0.11、0.12（样本=8777）；历史仅用于构建Γ/Ψ候选，不混入当月评估
# [INFO] 【参考库】year-month=1.01；同月历史窗口=无（年份=无，样本=0）；邻近窗口=0.10、0.11、0.12（样本=8777）；历史仅用于构建Γ/Ψ候选，不混入当月评估
# [INFO] 【数据切片】win=4(1.01) 样本数=2758，Month=01，Year_synth=1988
# [INFO] 【数据切片】win=4(1.01) 样本数=2758，Month=01，Year_synth=1988
# [INFO] 【示范库】Γ数=659，Ψ数=6683，历史同月来源窗口=无
# [INFO] 【示范库】Γ数=659，Ψ数=6683，历史同月来源窗口=无
# [INFO] 【相关度摘要】mean(E_pos)=0.0008，mean(E_neg)=0.0008，corr_diff=-0.0001
# [INFO] 【相关度摘要】mean(E_pos)=0.0008，mean(E_neg)=0.0008，corr_diff=-0.0001
# [INFO] 【三域概率摘要】mean(p_pos)=0.1947，mean(p_bnd)=0.1099，mean(p_neg)=0.6955
# [INFO] 【三域概率摘要】mean(p_pos)=0.1947，mean(p_bnd)=0.1099，mean(p_neg)=0.6955
# [INFO] 【网格信息】alpha网格=[0.55,0.90,0.02]，beta网格=[0.05,0.45,0.02]，可行格数=378
# [INFO] 【网格信息】alpha网格=[0.55,0.90,0.02]，beta网格=[0.05,0.45,0.02]，可行格数=378
# [INFO] 【目标面】best_score=0.0023，次优_score=0.0026，Δ=0.0004
# [INFO] 【目标面】best_score=0.0023，次优_score=0.0026，Δ=0.0004
# [INFO] 【漂移判级】PSI=0.0084，TV=0.0324，PosRateΔ=0.0352，等级=NONE，动作=无
# [INFO] 【漂移判级】PSI=0.0084，TV=0.0324，PosRateΔ=0.0352，等级=NONE，动作=无
# [INFO] 【重选后】α*=0.890，β*=0.050，EMA后=α=0.890/β=0.050，Δα=0.000，Δβ=0.000，ema=0.600，step_cap={'alpha':0.080,'beta':0.080}，BND占比=0.305，目标=0.0023(expected_cost)
# [INFO] 【重选后】α*=0.890，β*=0.050，EMA后=α=0.890/β=0.050，Δα=0.000，Δβ=0.000，ema=0.600，step_cap={'alpha':0.080,'beta':0.080}，BND占比=0.305，目标=0.0023(expected_cost)
# [INFO] 【增量】解锁标签月=1.01；合入季节桶=4；keep_history_ratio=0.30/容量=12；类均衡(POS/NEG)=1757/9778
# [INFO] 【增量】解锁标签月=1.01；合入季节桶=4；keep_history_ratio=0.30/容量=12；类均衡(POS/NEG)=1757/9778
# [INFO] 【参考库】year-month=1.02；同月历史窗口=无（年份=无，样本=0）；邻近窗口=0.11、0.12、1.01（样本=8495）；历史仅用于构建Γ/Ψ候选，不混入当月评估
# [INFO] 【参考库】year-month=1.02；同月历史窗口=无（年份=无，样本=0）；邻近窗口=0.11、0.12、1.01（样本=8495）；历史仅用于构建Γ/Ψ候选，不混入当月评估
# [INFO] 【数据切片】win=5(1.02) 样本数=2684，Month=02，Year_synth=1988
# [INFO] 【数据切片】win=5(1.02) 样本数=2684，Month=02，Year_synth=1988
# [INFO] 【示范库】Γ数=678，Ψ数=6387，历史同月来源窗口=无
# [INFO] 【示范库】Γ数=678，Ψ数=6387，历史同月来源窗口=无
# [INFO] 【相关度摘要】mean(E_pos)=0.0008，mean(E_neg)=0.0008，corr_diff=-0.0000
# [INFO] 【相关度摘要】mean(E_pos)=0.0008，mean(E_neg)=0.0008，corr_diff=-0.0000
# [INFO] 【三域概率摘要】mean(p_pos)=0.2103，mean(p_bnd)=0.1170，mean(p_neg)=0.6727
# [INFO] 【三域概率摘要】mean(p_pos)=0.2103，mean(p_bnd)=0.1170，mean(p_neg)=0.6727
# [INFO] 【网格信息】alpha网格=[0.55,0.90,0.02]，beta网格=[0.05,0.45,0.02]，可行格数=378
# [INFO] 【网格信息】alpha网格=[0.55,0.90,0.02]，beta网格=[0.05,0.45,0.02]，可行格数=378
# [INFO] 【目标面】best_score=0.0028，次优_score=0.0032，Δ=0.0004
# [INFO] 【目标面】best_score=0.0028，次优_score=0.0032，Δ=0.0004
# [INFO] 【漂移判级】PSI=0.0194，TV=0.0468，PosRateΔ=0.0130，等级=NONE，动作=无
# [INFO] 【漂移判级】PSI=0.0194，TV=0.0468，PosRateΔ=0.0130，等级=NONE，动作=无
# [INFO] 【重选后】α*=0.890，β*=0.050，EMA后=α=0.890/β=0.050，Δα=0.000，Δβ=0.000，ema=0.600，step_cap={'alpha':0.080,'beta':0.080}，BND占比=0.267，目标=0.0028(expected_cost)
# [INFO] 【重选后】α*=0.890，β*=0.050，EMA后=α=0.890/β=0.050，Δα=0.000，Δβ=0.000，ema=0.600，step_cap={'alpha':0.080,'beta':0.080}，BND占比=0.267，目标=0.0028(expected_cost)
# [INFO] 【增量】解锁标签月=1.02；合入季节桶=5；keep_history_ratio=0.30/容量=12；类均衡(POS/NEG)=2178/12041
# [INFO] 【增量】解锁标签月=1.02；合入季节桶=5；keep_history_ratio=0.30/容量=12；类均衡(POS/NEG)=2178/12041
# [INFO] 【参考库】year-month=1.03；同月历史窗口=无（年份=无，样本=0）；邻近窗口=0.12、1.01、1.02（样本=8296）；历史仅用于构建Γ/Ψ候选，不混入当月评估
# [INFO] 【参考库】year-month=1.03；同月历史窗口=无（年份=无，样本=0）；邻近窗口=0.12、1.01、1.02（样本=8296）；历史仅用于构建Γ/Ψ候选，不混入当月评估
# [INFO] 【数据切片】win=6(1.03) 样本数=2990，Month=03，Year_synth=1988
# [INFO] 【数据切片】win=6(1.03) 样本数=2990，Month=03，Year_synth=1988
# [INFO] 【示范库】Γ数=528，Ψ数=5896，历史同月来源窗口=无
# [INFO] 【示范库】Γ数=528，Ψ数=5896，历史同月来源窗口=无
# [INFO] 【相关度摘要】mean(E_pos)=0.0008，mean(E_neg)=0.0008，corr_diff=0.0001
# [INFO] 【相关度摘要】mean(E_pos)=0.0008，mean(E_neg)=0.0008，corr_diff=0.0001
# [INFO] 【三域概率摘要】mean(p_pos)=0.1997，mean(p_bnd)=0.1077，mean(p_neg)=0.6927
# [INFO] 【三域概率摘要】mean(p_pos)=0.1997，mean(p_bnd)=0.1077，mean(p_neg)=0.6927
# [INFO] 【网格信息】alpha网格=[0.55,0.90,0.02]，beta网格=[0.05,0.45,0.02]，可行格数=378
# [INFO] 【网格信息】alpha网格=[0.55,0.90,0.02]，beta网格=[0.05,0.45,0.02]，可行格数=378
# [INFO] 【目标面】best_score=0.0028，次优_score=0.0034，Δ=0.0005
# [INFO] 【目标面】best_score=0.0028，次优_score=0.0034，Δ=0.0005
# [INFO] 【漂移判级】PSI=0.0297，TV=0.0643，PosRateΔ=0.0175，等级=NONE，动作=无
# [INFO] 【漂移判级】PSI=0.0297，TV=0.0643，PosRateΔ=0.0175，等级=NONE，动作=无
# [INFO] 【重选后】α*=0.890，β*=0.050，EMA后=α=0.890/β=0.050，Δα=0.000，Δβ=0.000，ema=0.600，step_cap={'alpha':0.080,'beta':0.080}，BND占比=0.252，目标=0.0028(expected_cost)
# [INFO] 【重选后】α*=0.890，β*=0.050，EMA后=α=0.890/β=0.050，Δα=0.000，Δβ=0.000，ema=0.600，step_cap={'alpha':0.080,'beta':0.080}，BND占比=0.252，目标=0.0028(expected_cost)
# [INFO] 【增量】解锁标签月=1.03；合入季节桶=6；keep_history_ratio=0.30/容量=12；类均衡(POS/NEG)=2556/14653
# [INFO] 【增量】解锁标签月=1.03；合入季节桶=6；keep_history_ratio=0.30/容量=12；类均衡(POS/NEG)=2556/14653
# [INFO] 【参考库】year-month=1.04；同月历史窗口=无（年份=无，样本=0）；邻近窗口=1.01、1.02、1.03（样本=8432）；历史仅用于构建Γ/Ψ候选，不混入当月评估
# [INFO] 【参考库】year-month=1.04；同月历史窗口=无（年份=无，样本=0）；邻近窗口=1.01、1.02、1.03（样本=8432）；历史仅用于构建Γ/Ψ候选，不混入当月评估
# [INFO] 【数据切片】win=7(1.04) 样本数=2728，Month=04，Year_synth=1988
# [INFO] 【数据切片】win=7(1.04) 样本数=2728，Month=04，Year_synth=1988
# [INFO] 【示范库】Γ数=438，Ψ数=4959，历史同月来源窗口=无
# [INFO] 【示范库】Γ数=438，Ψ数=4959，历史同月来源窗口=无
# [INFO] 【相关度摘要】mean(E_pos)=0.0008，mean(E_neg)=0.0008，corr_diff=0.0001
# [INFO] 【相关度摘要】mean(E_pos)=0.0008，mean(E_neg)=0.0008，corr_diff=0.0001
# [INFO] 【三域概率摘要】mean(p_pos)=0.1844，mean(p_bnd)=0.1252，mean(p_neg)=0.6904
# [INFO] 【三域概率摘要】mean(p_pos)=0.1844，mean(p_bnd)=0.1252，mean(p_neg)=0.6904
# [INFO] 【网格信息】alpha网格=[0.55,0.90,0.02]，beta网格=[0.05,0.45,0.02]，可行格数=378
# [INFO] 【网格信息】alpha网格=[0.55,0.90,0.02]，beta网格=[0.05,0.45,0.02]，可行格数=378
# [INFO] 【目标面】best_score=0.0022，次优_score=0.0027，Δ=0.0004
# [INFO] 【目标面】best_score=0.0022，次优_score=0.0027，Δ=0.0004
# [INFO] 【漂移判级】PSI=0.0469，TV=0.0887，PosRateΔ=0.0325，等级=NONE，动作=无
# [INFO] 【漂移判级】PSI=0.0469，TV=0.0887，PosRateΔ=0.0325，等级=NONE，动作=无
# [INFO] 【重选后】α*=0.890，β*=0.050，EMA后=α=0.890/β=0.050，Δα=0.000，Δβ=0.000，ema=0.600，step_cap={'alpha':0.080,'beta':0.080}，BND占比=0.229，目标=0.0022(expected_cost)
# [INFO] 【重选后】α*=0.890，β*=0.050，EMA后=α=0.890/β=0.050，Δα=0.000，Δβ=0.000，ema=0.600，step_cap={'alpha':0.080,'beta':0.080}，BND占比=0.229，目标=0.0022(expected_cost)
# [INFO] 【增量】解锁标签月=1.04；合入季节桶=7；keep_history_ratio=0.30/容量=12；类均衡(POS/NEG)=2860/17077
# [INFO] 【增量】解锁标签月=1.04；合入季节桶=7；keep_history_ratio=0.30/容量=12；类均衡(POS/NEG)=2860/17077
# [INFO] 【参考库】year-month=1.05；同月历史窗口=无（年份=无，样本=0）；邻近窗口=1.02、1.03、1.04（样本=8402）；历史仅用于构建Γ/Ψ候选，不混入当月评估
# [INFO] 【参考库】year-month=1.05；同月历史窗口=无（年份=无，样本=0）；邻近窗口=1.02、1.03、1.04（样本=8402）；历史仅用于构建Γ/Ψ候选，不混入当月评估
# [INFO] 【数据切片】win=8(1.05) 样本数=2860，Month=05，Year_synth=1988
# [INFO] 【数据切片】win=8(1.05) 样本数=2860，Month=05，Year_synth=1988
# [INFO] 【示范库】Γ数=386，Ψ数=5063，历史同月来源窗口=无
# [INFO] 【示范库】Γ数=386，Ψ数=5063，历史同月来源窗口=无
# [INFO] 【相关度摘要】mean(E_pos)=0.0012，mean(E_neg)=0.0011，corr_diff=0.0001
# [INFO] 【相关度摘要】mean(E_pos)=0.0012，mean(E_neg)=0.0011，corr_diff=0.0001
# [INFO] 【三域概率摘要】mean(p_pos)=0.1847，mean(p_bnd)=0.0853，mean(p_neg)=0.7300
# [INFO] 【三域概率摘要】mean(p_pos)=0.1847，mean(p_bnd)=0.0853，mean(p_neg)=0.7300
# [INFO] 【网格信息】alpha网格=[0.55,0.90,0.02]，beta网格=[0.05,0.45,0.02]，可行格数=378
# [INFO] 【网格信息】alpha网格=[0.55,0.90,0.02]，beta网格=[0.05,0.45,0.02]，可行格数=378
# [INFO] 【目标面】best_score=0.0025，次优_score=0.0031，Δ=0.0005
# [INFO] 【目标面】best_score=0.0025，次优_score=0.0031，Δ=0.0005
# [INFO] 【漂移判级】PSI=0.0913，TV=0.1225，PosRateΔ=0.0306，等级=S1，动作=调σ
# [INFO] 【漂移判级】PSI=0.0913，TV=0.1225，PosRateΔ=0.0306，等级=S1，动作=调σ
# [INFO] 【重选后】α*=0.890，β*=0.050，EMA后=α=0.890/β=0.050，Δα=0.000，Δβ=0.000，ema=0.600，step_cap={'alpha':0.080,'beta':0.080}，BND占比=0.238，目标=0.0025(expected_cost)
# [INFO] 【重选后】α*=0.890，β*=0.050，EMA后=α=0.890/β=0.050，Δα=0.000，Δβ=0.000，ema=0.600，step_cap={'alpha':0.080,'beta':0.080}，BND占比=0.238，目标=0.0025(expected_cost)
# [INFO] 【增量】解锁标签月=1.05；合入季节桶=8；keep_history_ratio=0.30/容量=12；类均衡(POS/NEG)=3184/19613
# [INFO] 【增量】解锁标签月=1.05；合入季节桶=8；keep_history_ratio=0.30/容量=12；类均衡(POS/NEG)=3184/19613
# [INFO] 【参考库】year-month=1.06；同月历史窗口=无（年份=无，样本=0）；邻近窗口=1.03、1.04、1.05（样本=8578）；历史仅用于构建Γ/Ψ候选，不混入当月评估
# [INFO] 【参考库】year-month=1.06；同月历史窗口=无（年份=无，样本=0）；邻近窗口=1.03、1.04、1.05（样本=8578）；历史仅用于构建Γ/Ψ候选，不混入当月评估
# [INFO] 【数据切片】win=9(1.06) 样本数=2988，Month=06，Year_synth=1988
# [INFO] 【数据切片】win=9(1.06) 样本数=2988，Month=06，Year_synth=1988
# [INFO] 【示范库】Γ数=357，Ψ数=5238，历史同月来源窗口=无
# [INFO] 【示范库】Γ数=357，Ψ数=5238，历史同月来源窗口=无
# [INFO] 【相关度摘要】mean(E_pos)=0.0009，mean(E_neg)=0.0008，corr_diff=0.0001
# [INFO] 【相关度摘要】mean(E_pos)=0.0009，mean(E_neg)=0.0008，corr_diff=0.0001
# [INFO] 【三域概率摘要】mean(p_pos)=0.1669，mean(p_bnd)=0.1205，mean(p_neg)=0.7127
# [INFO] 【三域概率摘要】mean(p_pos)=0.1669，mean(p_bnd)=0.1205，mean(p_neg)=0.7127
# [INFO] 【网格信息】alpha网格=[0.55,0.90,0.02]，beta网格=[0.05,0.45,0.02]，可行格数=378
# [INFO] 【网格信息】alpha网格=[0.55,0.90,0.02]，beta网格=[0.05,0.45,0.02]，可行格数=378
# [INFO] 【目标面】best_score=0.0023，次优_score=0.0027，Δ=0.0005
# [INFO] 【目标面】best_score=0.0023，次优_score=0.0027，Δ=0.0005
# [INFO] 【漂移判级】PSI=0.0271，TV=0.0668，PosRateΔ=0.0535，等级=S1，动作=调σ
# [INFO] 【漂移判级】PSI=0.0271，TV=0.0668，PosRateΔ=0.0535，等级=S1，动作=调σ
# [INFO] 【重选后】α*=0.890，β*=0.050，EMA后=α=0.890/β=0.050，Δα=0.000，Δβ=0.000，ema=0.600，step_cap={'alpha':0.080,'beta':0.080}，BND占比=0.206，目标=0.0023(expected_cost)
# [INFO] 【重选后】α*=0.890，β*=0.050，EMA后=α=0.890/β=0.050，Δα=0.000，Δβ=0.000，ema=0.600，step_cap={'alpha':0.080,'beta':0.080}，BND占比=0.206，目标=0.0023(expected_cost)
# [INFO] 【增量】解锁标签月=1.06；合入季节桶=9；keep_history_ratio=0.30/容量=12；类均衡(POS/NEG)=3454/22331
# [INFO] 【增量】解锁标签月=1.06；合入季节桶=9；keep_history_ratio=0.30/容量=12；类均衡(POS/NEG)=3454/22331
# [INFO] 【参考库】year-month=1.07；同月历史窗口=无（年份=无，样本=0）；邻近窗口=1.04、1.05、1.06（样本=8576）；历史仅用于构建Γ/Ψ候选，不混入当月评估
# [INFO] 【参考库】year-month=1.07；同月历史窗口=无（年份=无，样本=0）；邻近窗口=1.04、1.05、1.06（样本=8576）；历史仅用于构建Γ/Ψ候选，不混入当月评估
# [INFO] 【数据切片】win=10(1.07) 样本数=2853，Month=07，Year_synth=1988
# [INFO] 【数据切片】win=10(1.07) 样本数=2853，Month=07，Year_synth=1988
# [INFO] 【示范库】Γ数=315，Ψ数=5314，历史同月来源窗口=无
# [INFO] 【示范库】Γ数=315，Ψ数=5314，历史同月来源窗口=无
# [INFO] 【相关度摘要】mean(E_pos)=0.0011，mean(E_neg)=0.0012，corr_diff=-0.0001
# [INFO] 【相关度摘要】mean(E_pos)=0.0011，mean(E_neg)=0.0012，corr_diff=-0.0001
# [INFO] 【三域概率摘要】mean(p_pos)=0.1591，mean(p_bnd)=0.0909，mean(p_neg)=0.7499
# [INFO] 【三域概率摘要】mean(p_pos)=0.1591，mean(p_bnd)=0.0909，mean(p_neg)=0.7499
# [INFO] 【网格信息】alpha网格=[0.55,0.90,0.02]，beta网格=[0.05,0.45,0.02]，可行格数=378
# [INFO] 【网格信息】alpha网格=[0.55,0.90,0.02]，beta网格=[0.05,0.45,0.02]，可行格数=378
# [INFO] 【目标面】best_score=0.0022，次优_score=0.0027，Δ=0.0005
# [INFO] 【目标面】best_score=0.0022，次优_score=0.0027，Δ=0.0005
# [INFO] 【漂移判级】PSI=0.1250，TV=0.1422，PosRateΔ=0.0324，等级=S1，动作=调σ
# [INFO] 【漂移判级】PSI=0.1250，TV=0.1422，PosRateΔ=0.0324，等级=S1，动作=调σ
# [INFO] 【重选后】α*=0.890，β*=0.050，EMA后=α=0.890/β=0.050，Δα=0.000，Δβ=0.000，ema=0.600，step_cap={'alpha':0.080,'beta':0.080}，BND占比=0.216，目标=0.0022(expected_cost)
# [INFO] 【重选后】α*=0.890，β*=0.050，EMA后=α=0.890/β=0.050，Δα=0.000，Δβ=0.000，ema=0.600，step_cap={'alpha':0.080,'beta':0.080}，BND占比=0.216，目标=0.0022(expected_cost)
# [INFO] 【增量】解锁标签月=1.07；合入季节桶=10；keep_history_ratio=0.30/容量=12；类均衡(POS/NEG)=3772/24866
# [INFO] 【增量】解锁标签月=1.07；合入季节桶=10；keep_history_ratio=0.30/容量=12；类均衡(POS/NEG)=3772/24866
# [INFO] 【参考库】year-month=1.08；同月历史窗口=无（年份=无，样本=0）；邻近窗口=1.05、1.06、1.07（样本=8701）；历史仅用于构建Γ/Ψ候选，不混入当月评估
# [INFO] 【参考库】year-month=1.08；同月历史窗口=无（年份=无，样本=0）；邻近窗口=1.05、1.06、1.07（样本=8701）；历史仅用于构建Γ/Ψ候选，不混入当月评估
# [INFO] 【数据切片】win=11(1.08) 样本数=2963，Month=08，Year_synth=1988
# [INFO] 【数据切片】win=11(1.08) 样本数=2963，Month=08，Year_synth=1988
# [INFO] 【示范库】Γ数=324，Ψ数=5366，历史同月来源窗口=无
# [INFO] 【示范库】Γ数=324，Ψ数=5366，历史同月来源窗口=无
# [INFO] 【相关度摘要】mean(E_pos)=0.0011，mean(E_neg)=0.0012，corr_diff=-0.0001
# [INFO] 【相关度摘要】mean(E_pos)=0.0011，mean(E_neg)=0.0012，corr_diff=-0.0001
# [INFO] 【三域概率摘要】mean(p_pos)=0.1693，mean(p_bnd)=0.0967，mean(p_neg)=0.7339
# [INFO] 【三域概率摘要】mean(p_pos)=0.1693，mean(p_bnd)=0.0967，mean(p_neg)=0.7339
# [INFO] 【网格信息】alpha网格=[0.55,0.90,0.02]，beta网格=[0.05,0.45,0.02]，可行格数=378
# [INFO] 【网格信息】alpha网格=[0.55,0.90,0.02]，beta网格=[0.05,0.45,0.02]，可行格数=378
# [INFO] 【目标面】best_score=0.0027，次优_score=0.0031，Δ=0.0004
# [INFO] 【目标面】best_score=0.0027，次优_score=0.0031，Δ=0.0004
# [INFO] 【漂移判级】PSI=0.0559，TV=0.0962，PosRateΔ=0.0430，等级=NONE，动作=无
# [INFO] 【漂移判级】PSI=0.0559，TV=0.0962，PosRateΔ=0.0430，等级=NONE，动作=无
# [INFO] 【重选后】α*=0.890，β*=0.050，EMA后=α=0.890/β=0.050，Δα=0.000，Δβ=0.000，ema=0.600，step_cap={'alpha':0.080,'beta':0.080}，BND占比=0.224，目标=0.0027(expected_cost)
# [INFO] 【重选后】α*=0.890，β*=0.050，EMA后=α=0.890/β=0.050，Δα=0.000，Δβ=0.000，ema=0.600，step_cap={'alpha':0.080,'beta':0.080}，BND占比=0.224，目标=0.0027(expected_cost)
# [INFO] 【增量】解锁标签月=1.08；合入季节桶=11；keep_history_ratio=0.30/容量=12；类均衡(POS/NEG)=4071/27530
# [INFO] 【增量】解锁标签月=1.08；合入季节桶=11；keep_history_ratio=0.30/容量=12；类均衡(POS/NEG)=4071/27530
# [INFO] 【参考库】year-month=1.09；同月历史窗口=无（年份=无，样本=0）；邻近窗口=1.06、1.07、1.08（样本=8804）；历史仅用于构建Γ/Ψ候选，不混入当月评估
# [INFO] 【参考库】year-month=1.09；同月历史窗口=无（年份=无，样本=0）；邻近窗口=1.06、1.07、1.08（样本=8804）；历史仅用于构建Γ/Ψ候选，不混入当月评估
# [INFO] 【数据切片】win=12(1.09) 样本数=2774，Month=09，Year_synth=1988
# [INFO] 【数据切片】win=12(1.09) 样本数=2774，Month=09，Year_synth=1988
# [INFO] 【示范库】Γ数=317，Ψ数=5443，历史同月来源窗口=无
# [INFO] 【示范库】Γ数=317，Ψ数=5443，历史同月来源窗口=无
# [INFO] 【相关度摘要】mean(E_pos)=0.0008，mean(E_neg)=0.0009，corr_diff=-0.0001
# [INFO] 【相关度摘要】mean(E_pos)=0.0008，mean(E_neg)=0.0009，corr_diff=-0.0001
# [INFO] 【三域概率摘要】mean(p_pos)=0.1511，mean(p_bnd)=0.0993，mean(p_neg)=0.7496
# [INFO] 【三域概率摘要】mean(p_pos)=0.1511，mean(p_bnd)=0.0993，mean(p_neg)=0.7496
# [INFO] 【网格信息】alpha网格=[0.55,0.90,0.02]，beta网格=[0.05,0.45,0.02]，可行格数=378
# [INFO] 【网格信息】alpha网格=[0.55,0.90,0.02]，beta网格=[0.05,0.45,0.02]，可行格数=378
# [INFO] 【目标面】best_score=0.0023，次优_score=0.0026，Δ=0.0003
# [INFO] 【目标面】best_score=0.0023，次优_score=0.0026，Δ=0.0003
# [INFO] 【漂移判级】PSI=0.0510，TV=0.0882，PosRateΔ=0.0617，等级=S1，动作=调σ
# [INFO] 【漂移判级】PSI=0.0510，TV=0.0882，PosRateΔ=0.0617，等级=S1，动作=调σ
# [INFO] 【重选后】α*=0.890，β*=0.050，EMA后=α=0.890/β=0.050，Δα=0.000，Δβ=0.000，ema=0.600，step_cap={'alpha':0.080,'beta':0.080}，BND占比=0.186，目标=0.0023(expected_cost)
# [INFO] 【重选后】α*=0.890，β*=0.050，EMA后=α=0.890/β=0.050，Δα=0.000，Δβ=0.000，ema=0.600，step_cap={'alpha':0.080,'beta':0.080}，BND占比=0.186，目标=0.0023(expected_cost)
# [INFO] 【增量】解锁标签月=1.09；合入季节桶=12；keep_history_ratio=0.30/容量=12；类均衡(POS/NEG)=4299/30076
# [INFO] 【增量】解锁标签月=1.09；合入季节桶=12；keep_history_ratio=0.30/容量=12；类均衡(POS/NEG)=4299/30076
# [INFO] 【参考库】year-month=1.10；同月历史窗口=0.10（年份=1987，样本=3040）；邻近窗口=1.07、1.08、1.09（样本=8590）；历史仅用于构建Γ/Ψ候选，不混入当月评估
# [INFO] 【参考库】year-month=1.10；同月历史窗口=0.10（年份=1987，样本=3040）；邻近窗口=1.07、1.08、1.09（样本=8590）；历史仅用于构建Γ/Ψ候选，不混入当月评估
# [INFO] 【数据切片】win=13(1.10) 样本数=3042，Month=10，Year_synth=1988
# [INFO] 【数据切片】win=13(1.10) 样本数=3042，Month=10，Year_synth=1988
# [INFO] 【示范库】Γ数=403，Ψ数=7188，历史同月来源窗口=0.10
# [INFO] 【示范库】Γ数=403，Ψ数=7188，历史同月来源窗口=0.10
# [INFO] 【相关度摘要】mean(E_pos)=0.0011，mean(E_neg)=0.0012，corr_diff=-0.0001
# [INFO] 【相关度摘要】mean(E_pos)=0.0011，mean(E_neg)=0.0012，corr_diff=-0.0001
# [INFO] 【三域概率摘要】mean(p_pos)=0.1775，mean(p_bnd)=0.0706，mean(p_neg)=0.7519
# [INFO] 【三域概率摘要】mean(p_pos)=0.1775，mean(p_bnd)=0.0706，mean(p_neg)=0.7519
# [INFO] 【网格信息】alpha网格=[0.55,0.90,0.02]，beta网格=[0.05,0.45,0.02]，可行格数=378
# [INFO] 【网格信息】alpha网格=[0.55,0.90,0.02]，beta网格=[0.05,0.45,0.02]，可行格数=378
# [INFO] 【目标面】best_score=0.0022，次优_score=0.0026，Δ=0.0004
# [INFO] 【目标面】best_score=0.0022，次优_score=0.0026，Δ=0.0004
# [INFO] 【漂移判级】PSI=0.0648，TV=0.1053，PosRateΔ=0.0512，等级=S1，动作=调σ
# [INFO] 【漂移判级】PSI=0.0648，TV=0.1053，PosRateΔ=0.0512，等级=S1，动作=调σ
# [INFO] 【重选后】α*=0.890，β*=0.050，EMA后=α=0.890/β=0.050，Δα=0.000，Δβ=0.000，ema=0.600，step_cap={'alpha':0.080,'beta':0.080}，BND占比=0.267，目标=0.0022(expected_cost)
# [INFO] 【重选后】α*=0.890，β*=0.050，EMA后=α=0.890/β=0.050，Δα=0.000，Δβ=0.000，ema=0.600，step_cap={'alpha':0.080,'beta':0.080}，BND占比=0.267，目标=0.0022(expected_cost)
# [INFO] 【增量】解锁标签月=1.10；合入季节桶=13；keep_history_ratio=0.30/容量=12；类均衡(POS/NEG)=4581/32836
# [INFO] 【增量】解锁标签月=1.10；合入季节桶=13；keep_history_ratio=0.30/容量=12；类均衡(POS/NEG)=4581/32836
# [INFO] 【参考库】year-month=1.11；同月历史窗口=0.11（年份=1987，样本=2883）；邻近窗口=1.08、1.09、1.10（样本=8779）；历史仅用于构建Γ/Ψ候选，不混入当月评估
# [INFO] 【参考库】year-month=1.11；同月历史窗口=0.11（年份=1987，样本=2883）；邻近窗口=1.08、1.09、1.10（样本=8779）；历史仅用于构建Γ/Ψ候选，不混入当月评估
# [INFO] 【数据切片】win=14(1.11) 样本数=2734，Month=11，Year_synth=1988
# [INFO] 【数据切片】win=14(1.11) 样本数=2734，Month=11，Year_synth=1988
# [INFO] 【示范库】Γ数=399，Ψ数=7102，历史同月来源窗口=0.11
# [INFO] 【示范库】Γ数=399，Ψ数=7102，历史同月来源窗口=0.11
# [INFO] 【相关度摘要】mean(E_pos)=0.0013，mean(E_neg)=0.0013，corr_diff=0.0000
# [INFO] 【相关度摘要】mean(E_pos)=0.0013，mean(E_neg)=0.0013，corr_diff=0.0000
# [INFO] 【三域概率摘要】mean(p_pos)=0.1851，mean(p_bnd)=0.0659，mean(p_neg)=0.7490
# [INFO] 【三域概率摘要】mean(p_pos)=0.1851，mean(p_bnd)=0.0659，mean(p_neg)=0.7490
# [INFO] 【网格信息】alpha网格=[0.55,0.90,0.02]，beta网格=[0.05,0.45,0.02]，可行格数=378
# [INFO] 【网格信息】alpha网格=[0.55,0.90,0.02]，beta网格=[0.05,0.45,0.02]，可行格数=378
# [INFO] 【目标面】best_score=0.0026，次优_score=0.0029，Δ=0.0003
# [INFO] 【目标面】best_score=0.0026，次优_score=0.0029，Δ=0.0003
# [INFO] 【漂移判级】PSI=0.0247，TV=0.0639，PosRateΔ=0.0064，等级=NONE，动作=无
# [INFO] 【漂移判级】PSI=0.0247，TV=0.0639，PosRateΔ=0.0064，等级=NONE，动作=无
# [INFO] 【重选后】α*=0.890，β*=0.050，EMA后=α=0.890/β=0.050，Δα=0.000，Δβ=0.000，ema=0.600，step_cap={'alpha':0.080,'beta':0.080}，BND占比=0.250，目标=0.0026(expected_cost)
# [INFO] 【重选后】α*=0.890，β*=0.050，EMA后=α=0.890/β=0.050，Δα=0.000，Δβ=0.000，ema=0.600，step_cap={'alpha':0.080,'beta':0.080}，BND占比=0.250，目标=0.0026(expected_cost)
# [INFO] 【增量】解锁标签月=1.11；合入季节桶=14；keep_history_ratio=0.30/容量=12；类均衡(POS/NEG)=4957/35194
# [INFO] 【增量】解锁标签月=1.11；合入季节桶=14；keep_history_ratio=0.30/容量=12；类均衡(POS/NEG)=4957/35194
# [INFO] 【参考库】year-month=1.12；同月历史窗口=0.12（年份=1987，样本=2854）；邻近窗口=1.09、1.10、1.11（样本=8550）；历史仅用于构建Γ/Ψ候选，不混入当月评估
# [INFO] 【参考库】year-month=1.12；同月历史窗口=0.12（年份=1987，样本=2854）；邻近窗口=1.09、1.10、1.11（样本=8550）；历史仅用于构建Γ/Ψ候选，不混入当月评估
# [INFO] 【数据切片】win=15(1.12) 样本数=2858，Month=12，Year_synth=1988
# [INFO] 【数据切片】win=15(1.12) 样本数=2858，Month=12，Year_synth=1988
# [INFO] 【示范库】Γ数=516，Ψ数=6743，历史同月来源窗口=0.12
# [INFO] 【示范库】Γ数=516，Ψ数=6743，历史同月来源窗口=0.12
# [INFO] 【相关度摘要】mean(E_pos)=0.0012，mean(E_neg)=0.0013，corr_diff=-0.0000
# [INFO] 【相关度摘要】mean(E_pos)=0.0012，mean(E_neg)=0.0013，corr_diff=-0.0000
# [INFO] 【三域概率摘要】mean(p_pos)=0.2007，mean(p_bnd)=0.0678，mean(p_neg)=0.7316
# [INFO] 【三域概率摘要】mean(p_pos)=0.2007，mean(p_bnd)=0.0678，mean(p_neg)=0.7316
# [INFO] 【网格信息】alpha网格=[0.55,0.90,0.02]，beta网格=[0.05,0.45,0.02]，可行格数=378
# [INFO] 【网格信息】alpha网格=[0.55,0.90,0.02]，beta网格=[0.05,0.45,0.02]，可行格数=378
# [INFO] 【目标面】best_score=0.0026，次优_score=0.0031，Δ=0.0005
# [INFO] 【目标面】best_score=0.0026，次优_score=0.0031，Δ=0.0005
# [INFO] 【漂移判级】PSI=0.0087，TV=0.0302，PosRateΔ=0.0202，等级=NONE，动作=无
# [INFO] 【漂移判级】PSI=0.0087，TV=0.0302，PosRateΔ=0.0202，等级=NONE，动作=无
# [INFO] 【重选后】α*=0.890，β*=0.050，EMA后=α=0.890/β=0.050，Δα=0.000，Δβ=0.000，ema=0.600，step_cap={'alpha':0.080,'beta':0.080}，BND占比=0.303，目标=0.0026(expected_cost)
# [INFO] 【重选后】α*=0.890，β*=0.050，EMA后=α=0.890/β=0.050，Δα=0.000，Δβ=0.000，ema=0.600，step_cap={'alpha':0.080,'beta':0.080}，BND占比=0.303，目标=0.0026(expected_cost)
# [INFO] 【增量】解锁标签月=1.12；合入季节桶=15；keep_history_ratio=0.30/容量=12；类均衡(POS/NEG)=5426/37583
# [INFO] 【增量】解锁标签月=1.12；合入季节桶=15；keep_history_ratio=0.30/容量=12；类均衡(POS/NEG)=5426/37583
# [INFO] 【参考库】year-month=2.01；同月历史窗口=1.01（年份=1988，样本=2758）；邻近窗口=1.10、1.11、1.12（样本=8634）；历史仅用于构建Γ/Ψ候选，不混入当月评估
# [INFO] 【参考库】year-month=2.01；同月历史窗口=1.01（年份=1988，样本=2758）；邻近窗口=1.10、1.11、1.12（样本=8634）；历史仅用于构建Γ/Ψ候选，不混入当月评估
# [INFO] 【数据切片】win=16(2.01) 样本数=2904，Month=01，Year_synth=1989
# [INFO] 【数据切片】win=16(2.01) 样本数=2904，Month=01，Year_synth=1989
# [INFO] 【示范库】Γ数=540，Ψ数=6618，历史同月来源窗口=1.01
# [INFO] 【示范库】Γ数=540，Ψ数=6618，历史同月来源窗口=1.01
# [INFO] 【相关度摘要】mean(E_pos)=0.0013，mean(E_neg)=0.0012，corr_diff=0.0001
# [INFO] 【相关度摘要】mean(E_pos)=0.0013，mean(E_neg)=0.0012，corr_diff=0.0001
# [INFO] 【三域概率摘要】mean(p_pos)=0.2240，mean(p_bnd)=0.0660，mean(p_neg)=0.7099
# [INFO] 【三域概率摘要】mean(p_pos)=0.2240，mean(p_bnd)=0.0660，mean(p_neg)=0.7099
# [INFO] 【网格信息】alpha网格=[0.55,0.90,0.02]，beta网格=[0.05,0.45,0.02]，可行格数=378
# [INFO] 【网格信息】alpha网格=[0.55,0.90,0.02]，beta网格=[0.05,0.45,0.02]，可行格数=378
# [INFO] 【目标面】best_score=0.0027，次优_score=0.0029，Δ=0.0003
# [INFO] 【目标面】best_score=0.0027，次优_score=0.0029，Δ=0.0003
# [INFO] 【漂移判级】PSI=0.0091，TV=0.0324，PosRateΔ=0.0044，等级=NONE，动作=无
# [INFO] 【漂移判级】PSI=0.0091，TV=0.0324，PosRateΔ=0.0044，等级=NONE，动作=无
# [INFO] 【重选后】α*=0.890，β*=0.050，EMA后=α=0.890/β=0.050，Δα=0.000，Δβ=0.000，ema=0.600，step_cap={'alpha':0.080,'beta':0.080}，BND占比=0.333，目标=0.0027(expected_cost)
# [INFO] 【重选后】α*=0.890，β*=0.050，EMA后=α=0.890/β=0.050，Δα=0.000，Δβ=0.000，ema=0.600，step_cap={'alpha':0.080,'beta':0.080}，BND占比=0.333，目标=0.0027(expected_cost)
# [INFO] 【增量】解锁标签月=2.01；合入季节桶=16；keep_history_ratio=0.30/容量=12；类均衡(POS/NEG)=5831/40082
# [INFO] 【增量】解锁标签月=2.01；合入季节桶=16；keep_history_ratio=0.30/容量=12；类均衡(POS/NEG)=5831/40082
# [INFO] 【参考库】year-month=2.02；同月历史窗口=1.02（年份=1988，样本=2684）；邻近窗口=1.11、1.12、2.01（样本=8496）；历史仅用于构建Γ/Ψ候选，不混入当月评估
# [INFO] 【参考库】year-month=2.02；同月历史窗口=1.02（年份=1988，样本=2684）；邻近窗口=1.11、1.12、2.01（样本=8496）；历史仅用于构建Γ/Ψ候选，不混入当月评估
# [INFO] 【数据切片】win=17(2.02) 样本数=2537，Month=02，Year_synth=1989
# [INFO] 【数据切片】win=17(2.02) 样本数=2537，Month=02，Year_synth=1989
# [INFO] 【示范库】Γ数=564，Ψ数=6460，历史同月来源窗口=1.02
# [INFO] 【示范库】Γ数=564，Ψ数=6460，历史同月来源窗口=1.02
# [INFO] 【相关度摘要】mean(E_pos)=0.0012，mean(E_neg)=0.0013，corr_diff=-0.0001
# [INFO] 【相关度摘要】mean(E_pos)=0.0012，mean(E_neg)=0.0013，corr_diff=-0.0001
# [INFO] 【三域概率摘要】mean(p_pos)=0.2218，mean(p_bnd)=0.0735，mean(p_neg)=0.7046
# [INFO] 【三域概率摘要】mean(p_pos)=0.2218，mean(p_bnd)=0.0735，mean(p_neg)=0.7046
# [INFO] 【网格信息】alpha网格=[0.55,0.90,0.02]，beta网格=[0.05,0.45,0.02]，可行格数=377
# [INFO] 【网格信息】alpha网格=[0.55,0.90,0.02]，beta网格=[0.05,0.45,0.02]，可行格数=377
# [INFO] 【目标面】best_score=0.0029，次优_score=0.0032，Δ=0.0003
# [INFO] 【目标面】best_score=0.0029，次优_score=0.0032，Δ=0.0003
# [INFO] 【漂移判级】PSI=0.0169，TV=0.0449，PosRateΔ=0.0295，等级=NONE，动作=无
# [INFO] 【漂移判级】PSI=0.0169，TV=0.0449，PosRateΔ=0.0295，等级=NONE，动作=无
# [INFO] 【重选后】α*=0.870，β*=0.050，EMA后=α=0.878/β=0.050，Δα=0.012，Δβ=0.000，ema=0.600，step_cap={'alpha':0.080,'beta':0.080}，BND占比=0.346，目标=0.0028(expected_cost)
# [INFO] 【重选后】α*=0.870，β*=0.050，EMA后=α=0.878/β=0.050，Δα=0.012，Δβ=0.000，ema=0.600，step_cap={'alpha':0.080,'beta':0.080}，BND占比=0.346，目标=0.0028(expected_cost)
# [INFO] 【增量】解锁标签月=2.02；合入季节桶=17；keep_history_ratio=0.30/容量=12；类均衡(POS/NEG)=6271/42179
# [INFO] 【增量】解锁标签月=2.02；合入季节桶=17；keep_history_ratio=0.30/容量=12；类均衡(POS/NEG)=6271/42179
# [INFO] 【参考库】year-month=2.03；同月历史窗口=1.03（年份=1988，样本=2990）；邻近窗口=1.12、2.01、2.02（样本=8299）；历史仅用于构建Γ/Ψ候选，不混入当月评估
# [INFO] 【参考库】year-month=2.03；同月历史窗口=1.03（年份=1988，样本=2990）；邻近窗口=1.12、2.01、2.02（样本=8299）；历史仅用于构建Γ/Ψ候选，不混入当月评估
# [INFO] 【数据切片】win=18(2.03) 样本数=2776，Month=03，Year_synth=1989
# [INFO] 【数据切片】win=18(2.03) 样本数=2776，Month=03，Year_synth=1989
# [INFO] 【示范库】Γ数=564，Ψ数=6512，历史同月来源窗口=1.03
# [INFO] 【示范库】Γ数=564，Ψ数=6512，历史同月来源窗口=1.03
# [INFO] 【相关度摘要】mean(E_pos)=0.0009，mean(E_neg)=0.0009，corr_diff=0.0001
# [INFO] 【相关度摘要】mean(E_pos)=0.0009，mean(E_neg)=0.0009，corr_diff=0.0001
# [INFO] 【三域概率摘要】mean(p_pos)=0.2075，mean(p_bnd)=0.0848，mean(p_neg)=0.7077
# [INFO] 【三域概率摘要】mean(p_pos)=0.2075，mean(p_bnd)=0.0848，mean(p_neg)=0.7077
# [INFO] 【网格信息】alpha网格=[0.55,0.90,0.02]，beta网格=[0.05,0.45,0.02]，可行格数=378
# [INFO] 【网格信息】alpha网格=[0.55,0.90,0.02]，beta网格=[0.05,0.45,0.02]，可行格数=378
# [INFO] 【目标面】best_score=0.0027，次优_score=0.0032，Δ=0.0004
# [INFO] 【目标面】best_score=0.0027，次优_score=0.0032，Δ=0.0004
# [INFO] 【漂移判级】PSI=0.0063，TV=0.0312，PosRateΔ=0.0528，等级=S1，动作=调σ
# [INFO] 【漂移判级】PSI=0.0063，TV=0.0312，PosRateΔ=0.0528，等级=S1，动作=调σ
# [INFO] 【重选后】α*=0.890，β*=0.050，EMA后=α=0.885/β=0.050，Δα=0.007，Δβ=0.000，ema=0.600，step_cap={'alpha':0.080,'beta':0.080}，BND占比=0.298，目标=0.0028(expected_cost)
# [INFO] 【重选后】α*=0.890，β*=0.050，EMA后=α=0.885/β=0.050，Δα=0.007，Δβ=0.000，ema=0.600，step_cap={'alpha':0.080,'beta':0.080}，BND占比=0.298，目标=0.0028(expected_cost)
# [INFO] 【增量】解锁标签月=2.03；合入季节桶=18；keep_history_ratio=0.30/容量=12；类均衡(POS/NEG)=6817/44409
# [INFO] 【增量】解锁标签月=2.03；合入季节桶=18；keep_history_ratio=0.30/容量=12；类均衡(POS/NEG)=6817/44409
# [INFO] 【参考库】year-month=2.04；同月历史窗口=1.04（年份=1988，样本=2728）；邻近窗口=2.01、2.02、2.03（样本=8217）；历史仅用于构建Γ/Ψ候选，不混入当月评估
# [INFO] 【参考库】year-month=2.04；同月历史窗口=1.04（年份=1988，样本=2728）；邻近窗口=2.01、2.02、2.03（样本=8217）；历史仅用于构建Γ/Ψ候选，不混入当月评估
# [INFO] 【数据切片】win=19(2.04) 样本数=2659，Month=04，Year_synth=1989
# [INFO] 【数据切片】win=19(2.04) 样本数=2659，Month=04，Year_synth=1989
# [INFO] 【示范库】Γ数=566，Ψ数=6319，历史同月来源窗口=1.04
# [INFO] 【示范库】Γ数=566，Ψ数=6319，历史同月来源窗口=1.04
# [INFO] 【相关度摘要】mean(E_pos)=0.0014，mean(E_neg)=0.0013，corr_diff=0.0001
# [INFO] 【相关度摘要】mean(E_pos)=0.0014，mean(E_neg)=0.0013，corr_diff=0.0001
# [INFO] 【三域概率摘要】mean(p_pos)=0.2221，mean(p_bnd)=0.0756，mean(p_neg)=0.7023
# [INFO] 【三域概率摘要】mean(p_pos)=0.2221，mean(p_bnd)=0.0756，mean(p_neg)=0.7023
# [INFO] 【网格信息】alpha网格=[0.55,0.90,0.02]，beta网格=[0.05,0.45,0.02]，可行格数=378
# [INFO] 【网格信息】alpha网格=[0.55,0.90,0.02]，beta网格=[0.05,0.45,0.02]，可行格数=378
# [INFO] 【目标面】best_score=0.0028，次优_score=0.0032，Δ=0.0004
# [INFO] 【目标面】best_score=0.0028，次优_score=0.0032，Δ=0.0004
# [INFO] 【漂移判级】PSI=0.0177，TV=0.0510，PosRateΔ=0.0536，等级=S1，动作=调σ
# [INFO] 【漂移判级】PSI=0.0177，TV=0.0510，PosRateΔ=0.0536，等级=S1，动作=调σ
# [INFO] 【重选后】α*=0.890，β*=0.050，EMA后=α=0.888/β=0.050，Δα=0.003，Δβ=0.000，ema=0.600，step_cap={'alpha':0.080,'beta':0.080}，BND占比=0.335，目标=0.0028(expected_cost)
# [INFO] 【重选后】α*=0.890，β*=0.050，EMA后=α=0.888/β=0.050，Δα=0.003，Δβ=0.000，ema=0.600，step_cap={'alpha':0.080,'beta':0.080}，BND占比=0.335，目标=0.0028(expected_cost)
# [INFO] 【增量】解锁标签月=2.04；合入季节桶=19；keep_history_ratio=0.30/容量=12；类均衡(POS/NEG)=7057/46828
# [INFO] 【增量】解锁标签月=2.04；合入季节桶=19；keep_history_ratio=0.30/容量=12；类均衡(POS/NEG)=7057/46828
# [INFO] 【参考库】year-month=2.05；同月历史窗口=1.05（年份=1988，样本=2860）；邻近窗口=2.02、2.03、2.04（样本=7972）；历史仅用于构建Γ/Ψ候选，不混入当月评估
# [INFO] 【参考库】year-month=2.05；同月历史窗口=1.05（年份=1988，样本=2860）；邻近窗口=2.02、2.03、2.04（样本=7972）；历史仅用于构建Γ/Ψ候选，不混入当月评估
# [INFO] 【数据切片】win=20(2.05) 样本数=2839，Month=05，Year_synth=1989
# [INFO] 【数据切片】win=20(2.05) 样本数=2839，Month=05，Year_synth=1989
# [INFO] 【示范库】Γ数=526，Ψ数=6333，历史同月来源窗口=1.05
# [INFO] 【示范库】Γ数=526，Ψ数=6333，历史同月来源窗口=1.05
# [INFO] 【相关度摘要】mean(E_pos)=0.0011，mean(E_neg)=0.0013，corr_diff=-0.0002
# [INFO] 【相关度摘要】mean(E_pos)=0.0011，mean(E_neg)=0.0013，corr_diff=-0.0002
# [INFO] 【三域概率摘要】mean(p_pos)=0.2010，mean(p_bnd)=0.0684，mean(p_neg)=0.7306
# [INFO] 【三域概率摘要】mean(p_pos)=0.2010，mean(p_bnd)=0.0684，mean(p_neg)=0.7306
# [INFO] 【网格信息】alpha网格=[0.55,0.90,0.02]，beta网格=[0.05,0.45,0.02]，可行格数=378
# [INFO] 【网格信息】alpha网格=[0.55,0.90,0.02]，beta网格=[0.05,0.45,0.02]，可行格数=378
# [INFO] 【目标面】best_score=0.0027，次优_score=0.0032，Δ=0.0004
# [INFO] 【目标面】best_score=0.0027，次优_score=0.0032，Δ=0.0004
# [INFO] 【漂移判级】PSI=0.0045，TV=0.0230，PosRateΔ=0.0164，等级=NONE，动作=无
# [INFO] 【漂移判级】PSI=0.0045，TV=0.0230，PosRateΔ=0.0164，等级=NONE，动作=无
# [INFO] 【重选后】α*=0.890，β*=0.050，EMA后=α=0.889/β=0.050，Δα=0.001，Δβ=0.000，ema=0.600，step_cap={'alpha':0.080,'beta':0.080}，BND占比=0.313，目标=0.0028(expected_cost)
# [INFO] 【重选后】α*=0.890，β*=0.050，EMA后=α=0.889/β=0.050，Δα=0.001，Δβ=0.000，ema=0.600，step_cap={'alpha':0.080,'beta':0.080}，BND占比=0.313，目标=0.0028(expected_cost)
# [INFO] 【增量】解锁标签月=2.05；合入季节桶=20；keep_history_ratio=0.30/容量=12；类均衡(POS/NEG)=7419/49305
# [INFO] 【增量】解锁标签月=2.05；合入季节桶=20；keep_history_ratio=0.30/容量=12；类均衡(POS/NEG)=7419/49305
# [INFO] 【参考库】year-month=2.06；同月历史窗口=1.06（年份=1988，样本=2988）；邻近窗口=2.03、2.04、2.05（样本=8274）；历史仅用于构建Γ/Ψ候选，不混入当月评估
# [INFO] 【参考库】year-month=2.06；同月历史窗口=1.06（年份=1988，样本=2988）；邻近窗口=2.03、2.04、2.05（样本=8274）；历史仅用于构建Γ/Ψ候选，不混入当月评估
# [INFO] 【数据切片】win=21(2.06) 样本数=2752，Month=06，Year_synth=1989
# [INFO] 【数据切片】win=21(2.06) 样本数=2752，Month=06，Year_synth=1989
# [INFO] 【示范库】Γ数=478，Ψ数=6691，历史同月来源窗口=1.06
# [INFO] 【示范库】Γ数=478，Ψ数=6691，历史同月来源窗口=1.06
# [INFO] 【相关度摘要】mean(E_pos)=0.0013，mean(E_neg)=0.0013，corr_diff=-0.0000
# [INFO] 【相关度摘要】mean(E_pos)=0.0013，mean(E_neg)=0.0013，corr_diff=-0.0000
# [INFO] 【三域概率摘要】mean(p_pos)=0.2107，mean(p_bnd)=0.0621，mean(p_neg)=0.7272
# [INFO] 【三域概率摘要】mean(p_pos)=0.2107，mean(p_bnd)=0.0621，mean(p_neg)=0.7272
# [INFO] 【网格信息】alpha网格=[0.55,0.90,0.02]，beta网格=[0.05,0.45,0.02]，可行格数=378
# [INFO] 【网格信息】alpha网格=[0.55,0.90,0.02]，beta网格=[0.05,0.45,0.02]，可行格数=378
# [INFO] 【目标面】best_score=0.0029，次优_score=0.0033，Δ=0.0004
# [INFO] 【目标面】best_score=0.0029，次优_score=0.0033，Δ=0.0004
# [INFO] 【漂移判级】PSI=0.0036，TV=0.0158，PosRateΔ=0.0414，等级=NONE，动作=无
# [INFO] 【漂移判级】PSI=0.0036，TV=0.0158，PosRateΔ=0.0414，等级=NONE，动作=无
# [INFO] 【重选后】α*=0.890，β*=0.050，EMA后=α=0.890/β=0.050，Δα=0.000，Δβ=0.000，ema=0.600，step_cap={'alpha':0.080,'beta':0.080}，BND占比=0.315，目标=0.0029(expected_cost)
# [INFO] 【重选后】α*=0.890，β*=0.050，EMA后=α=0.890/β=0.050，Δα=0.000，Δβ=0.000，ema=0.600，step_cap={'alpha':0.080,'beta':0.080}，BND占比=0.315，目标=0.0029(expected_cost)
# [INFO] 【增量】解锁标签月=2.06；合入季节桶=21；keep_history_ratio=0.30/容量=12；类均衡(POS/NEG)=7929/51547
# [INFO] 【增量】解锁标签月=2.06；合入季节桶=21；keep_history_ratio=0.30/容量=12；类均衡(POS/NEG)=7929/51547
# [INFO] 【参考库】year-month=2.07；同月历史窗口=1.07（年份=1988，样本=2853）；邻近窗口=2.04、2.05、2.06（样本=8250）；历史仅用于构建Γ/Ψ候选，不混入当月评估
# [INFO] 【参考库】year-month=2.07；同月历史窗口=1.07（年份=1988，样本=2853）；邻近窗口=2.04、2.05、2.06（样本=8250）；历史仅用于构建Γ/Ψ候选，不混入当月评估
# [INFO] 【数据切片】win=22(2.07) 样本数=2785，Month=07，Year_synth=1989
# [INFO] 【数据切片】win=22(2.07) 样本数=2785，Month=07，Year_synth=1989
# [INFO] 【示范库】Γ数=491，Ψ数=6567，历史同月来源窗口=1.07
# [INFO] 【示范库】Γ数=491，Ψ数=6567，历史同月来源窗口=1.07
# [INFO] 【相关度摘要】mean(E_pos)=0.0011，mean(E_neg)=0.0013，corr_diff=-0.0002
# [INFO] 【相关度摘要】mean(E_pos)=0.0011，mean(E_neg)=0.0013，corr_diff=-0.0002
# [INFO] 【三域概率摘要】mean(p_pos)=0.1912，mean(p_bnd)=0.0703，mean(p_neg)=0.7385
# [INFO] 【三域概率摘要】mean(p_pos)=0.1912，mean(p_bnd)=0.0703，mean(p_neg)=0.7385
# [INFO] 【网格信息】alpha网格=[0.55,0.90,0.02]，beta网格=[0.05,0.45,0.02]，可行格数=378
# [INFO] 【网格信息】alpha网格=[0.55,0.90,0.02]，beta网格=[0.05,0.45,0.02]，可行格数=378
# [INFO] 【目标面】best_score=0.0030，次优_score=0.0035，Δ=0.0004
# [INFO] 【目标面】best_score=0.0030，次优_score=0.0035，Δ=0.0004
# [INFO] 【漂移判级】PSI=0.0264，TV=0.0617，PosRateΔ=0.0123，等级=NONE，动作=无
# [INFO] 【漂移判级】PSI=0.0264，TV=0.0617，PosRateΔ=0.0123，等级=NONE，动作=无
# [INFO] 【重选后】α*=0.890，β*=0.050，EMA后=α=0.890/β=0.050，Δα=0.000，Δβ=0.000，ema=0.600，step_cap={'alpha':0.080,'beta':0.080}，BND占比=0.264，目标=0.0030(expected_cost)
# [INFO] 【重选后】α*=0.890，β*=0.050，EMA后=α=0.890/β=0.050，Δα=0.000，Δβ=0.000，ema=0.600，step_cap={'alpha':0.080,'beta':0.080}，BND占比=0.264，目标=0.0030(expected_cost)
# [INFO] 【增量】解锁标签月=2.07；合入季节桶=22；keep_history_ratio=0.30/容量=12；类均衡(POS/NEG)=8364/53897
# [INFO] 【增量】解锁标签月=2.07；合入季节桶=22；keep_history_ratio=0.30/容量=12；类均衡(POS/NEG)=8364/53897
# [INFO] 【参考库】year-month=2.08；同月历史窗口=1.08（年份=1988，样本=2963）；邻近窗口=2.05、2.06、2.07（样本=8376）；历史仅用于构建Γ/Ψ候选，不混入当月评估
# [INFO] 【参考库】year-month=2.08；同月历史窗口=1.08（年份=1988，样本=2963）；邻近窗口=2.05、2.06、2.07（样本=8376）；历史仅用于构建Γ/Ψ候选，不混入当月评估
# [INFO] 【数据切片】win=23(2.08) 样本数=2743，Month=08，Year_synth=1989
# [INFO] 【数据切片】win=23(2.08) 样本数=2743，Month=08，Year_synth=1989
# [INFO] 【示范库】Γ数=546，Ψ数=6639，历史同月来源窗口=1.08
# [INFO] 【示范库】Γ数=546，Ψ数=6639，历史同月来源窗口=1.08
# [INFO] 【相关度摘要】mean(E_pos)=0.0013，mean(E_neg)=0.0012，corr_diff=0.0000
# [INFO] 【相关度摘要】mean(E_pos)=0.0013，mean(E_neg)=0.0012，corr_diff=0.0000
# [INFO] 【三域概率摘要】mean(p_pos)=0.2152，mean(p_bnd)=0.0700，mean(p_neg)=0.7148
# [INFO] 【三域概率摘要】mean(p_pos)=0.2152，mean(p_bnd)=0.0700，mean(p_neg)=0.7148
# [INFO] 【网格信息】alpha网格=[0.55,0.90,0.02]，beta网格=[0.05,0.45,0.02]，可行格数=378
# [INFO] 【网格信息】alpha网格=[0.55,0.90,0.02]，beta网格=[0.05,0.45,0.02]，可行格数=378
# [INFO] 【目标面】best_score=0.0026，次优_score=0.0031，Δ=0.0005
# [INFO] 【目标面】best_score=0.0026，次优_score=0.0031，Δ=0.0005
# [INFO] 【漂移判级】PSI=0.0044，TV=0.0177，PosRateΔ=0.0099，等级=NONE，动作=无
# [INFO] 【漂移判级】PSI=0.0044，TV=0.0177，PosRateΔ=0.0099，等级=NONE，动作=无
# [INFO] 【重选后】α*=0.890，β*=0.050，EMA后=α=0.890/β=0.050，Δα=0.000，Δβ=0.000，ema=0.600，step_cap={'alpha':0.080,'beta':0.080}，BND占比=0.332，目标=0.0026(expected_cost)
# [INFO] 【重选后】α*=0.890，β*=0.050，EMA后=α=0.890/β=0.050，Δα=0.000，Δβ=0.000，ema=0.600，step_cap={'alpha':0.080,'beta':0.080}，BND占比=0.332，目标=0.0026(expected_cost)
# [INFO] 【增量】解锁标签月=2.08；合入季节桶=23；keep_history_ratio=0.30/容量=12；类均衡(POS/NEG)=8786/56218
# [INFO] 【增量】解锁标签月=2.08；合入季节桶=23；keep_history_ratio=0.30/容量=12；类均衡(POS/NEG)=8786/56218
# [INFO] 【参考库】year-month=2.09；同月历史窗口=1.09（年份=1988，样本=2774）；邻近窗口=2.06、2.07、2.08（样本=8280）；历史仅用于构建Γ/Ψ候选，不混入当月评估
# [INFO] 【参考库】year-month=2.09；同月历史窗口=1.09（年份=1988，样本=2774）；邻近窗口=2.06、2.07、2.08（样本=8280）；历史仅用于构建Γ/Ψ候选，不混入当月评估
# [INFO] 【数据切片】win=24(2.09) 样本数=2818，Month=09，Year_synth=1989
# [INFO] 【数据切片】win=24(2.09) 样本数=2818，Month=09，Year_synth=1989
# [INFO] 【示范库】Γ数=543，Ψ数=6448，历史同月来源窗口=1.09
# [INFO] 【示范库】Γ数=543，Ψ数=6448，历史同月来源窗口=1.09
# [INFO] 【相关度摘要】mean(E_pos)=0.0012，mean(E_neg)=0.0013，corr_diff=-0.0002
# [INFO] 【相关度摘要】mean(E_pos)=0.0012，mean(E_neg)=0.0013，corr_diff=-0.0002
# [INFO] 【三域概率摘要】mean(p_pos)=0.2130，mean(p_bnd)=0.0698，mean(p_neg)=0.7171
# [INFO] 【三域概率摘要】mean(p_pos)=0.2130，mean(p_bnd)=0.0698，mean(p_neg)=0.7171
# [INFO] 【网格信息】alpha网格=[0.55,0.90,0.02]，beta网格=[0.05,0.45,0.02]，可行格数=378
# [INFO] 【网格信息】alpha网格=[0.55,0.90,0.02]，beta网格=[0.05,0.45,0.02]，可行格数=378
# [INFO] 【目标面】best_score=0.0029，次优_score=0.0035，Δ=0.0006
# [INFO] 【目标面】best_score=0.0029，次优_score=0.0035，Δ=0.0006
# [INFO] 【漂移判级】PSI=0.0045，TV=0.0172，PosRateΔ=0.0197，等级=NONE，动作=无
# [INFO] 【漂移判级】PSI=0.0045，TV=0.0172，PosRateΔ=0.0197，等级=NONE，动作=无
# [INFO] 【重选后】α*=0.890，β*=0.050，EMA后=α=0.890/β=0.050，Δα=0.000，Δβ=0.000，ema=0.600，step_cap={'alpha':0.080,'beta':0.080}，BND占比=0.334，目标=0.0029(expected_cost)
# [INFO] 【重选后】α*=0.890，β*=0.050，EMA后=α=0.890/β=0.050，Δα=0.000，Δβ=0.000，ema=0.600，step_cap={'alpha':0.080,'beta':0.080}，BND占比=0.334，目标=0.0029(expected_cost)
# [INFO] 【增量】解锁标签月=2.09；合入季节桶=24；keep_history_ratio=0.30/容量=12；类均衡(POS/NEG)=9136/58686
# [INFO] 【增量】解锁标签月=2.09；合入季节桶=24；keep_history_ratio=0.30/容量=12；类均衡(POS/NEG)=9136/58686
# [INFO] 【参考库】year-month=2.10；同月历史窗口=0.10、1.10（年份=1987、1988，样本=6082）；邻近窗口=2.07、2.08、2.09（样本=8346）；历史仅用于构建Γ/Ψ候选，不混入当月评估
# [INFO] 【参考库】year-month=2.10；同月历史窗口=0.10、1.10（年份=1987、1988，样本=6082）；邻近窗口=2.07、2.08、2.09（样本=8346）；历史仅用于构建Γ/Ψ候选，不混入当月评估
# [INFO] 【数据切片】win=25(2.10) 样本数=2871，Month=10，Year_synth=1989
# [INFO] 【数据切片】win=25(2.10) 样本数=2871，Month=10，Year_synth=1989
# [INFO] 【示范库】Γ数=601，Ψ数=8362，历史同月来源窗口=0.10、1.10
# [INFO] 【示范库】Γ数=601，Ψ数=8362，历史同月来源窗口=0.10、1.10
# [INFO] 【相关度摘要】mean(E_pos)=0.0012，mean(E_neg)=0.0013，corr_diff=-0.0001
# [INFO] 【相关度摘要】mean(E_pos)=0.0012，mean(E_neg)=0.0013，corr_diff=-0.0001
# [INFO] 【三域概率摘要】mean(p_pos)=0.2305，mean(p_bnd)=0.0477，mean(p_neg)=0.7218
# [INFO] 【三域概率摘要】mean(p_pos)=0.2305，mean(p_bnd)=0.0477，mean(p_neg)=0.7218
# [INFO] 【网格信息】alpha网格=[0.55,0.90,0.02]，beta网格=[0.05,0.45,0.02]，可行格数=377
# [INFO] 【网格信息】alpha网格=[0.55,0.90,0.02]，beta网格=[0.05,0.45,0.02]，可行格数=377
# [INFO] 【目标面】best_score=0.0033，次优_score=0.0037，Δ=0.0004
# [INFO] 【目标面】best_score=0.0033，次优_score=0.0037，Δ=0.0004
# [INFO] 【漂移判级】PSI=0.0084，TV=0.0372，PosRateΔ=0.0101，等级=NONE，动作=无
# [INFO] 【漂移判级】PSI=0.0084，TV=0.0372，PosRateΔ=0.0101，等级=NONE，动作=无
# [INFO] 【重选后】α*=0.870，β*=0.050，EMA后=α=0.870/β=0.050，Δα=0.020，Δβ=0.000，ema=0.600，step_cap={'alpha':0.080,'beta':0.080}，BND占比=0.346，目标=0.0033(expected_cost)
# [INFO] 【重选后】α*=0.870，β*=0.050，EMA后=α=0.870/β=0.050，Δα=0.020，Δβ=0.000，ema=0.600，step_cap={'alpha':0.080,'beta':0.080}，BND占比=0.346，目标=0.0033(expected_cost)
# [INFO] 【增量】解锁标签月=2.10；合入季节桶=25；keep_history_ratio=0.30/容量=12；类均衡(POS/NEG)=9520/61173
# [INFO] 【增量】解锁标签月=2.10；合入季节桶=25；keep_history_ratio=0.30/容量=12；类均衡(POS/NEG)=9520/61173
# [INFO] 【参考库】year-month=2.11；同月历史窗口=0.11、1.11（年份=1987、1988，样本=5617）；邻近窗口=2.08、2.09、2.10（样本=8432）；历史仅用于构建Γ/Ψ候选，不混入当月评估
# [INFO] 【参考库】year-month=2.11；同月历史窗口=0.11、1.11（年份=1987、1988，样本=5617）；邻近窗口=2.08、2.09、2.10（样本=8432）；历史仅用于构建Γ/Ψ候选，不混入当月评估
# [INFO] 【数据切片】win=26(2.11) 样本数=2771，Month=11，Year_synth=1989
# [INFO] 【数据切片】win=26(2.11) 样本数=2771，Month=11，Year_synth=1989
# [INFO] 【示范库】Γ数=623，Ψ数=8060，历史同月来源窗口=0.11、1.11
# [INFO] 【示范库】Γ数=623，Ψ数=8060，历史同月来源窗口=0.11、1.11
# [INFO] 【相关度摘要】mean(E_pos)=0.0013，mean(E_neg)=0.0013，corr_diff=0.0000
# [INFO] 【相关度摘要】mean(E_pos)=0.0013，mean(E_neg)=0.0013，corr_diff=0.0000
# [INFO] 【三域概率摘要】mean(p_pos)=0.2458，mean(p_bnd)=0.0543，mean(p_neg)=0.6999
# [INFO] 【三域概率摘要】mean(p_pos)=0.2458，mean(p_bnd)=0.0543，mean(p_neg)=0.6999
# [INFO] 【网格信息】alpha网格=[0.55,0.90,0.02]，beta网格=[0.05,0.45,0.02]，可行格数=365
# [INFO] 【网格信息】alpha网格=[0.55,0.90,0.02]，beta网格=[0.05,0.45,0.02]，可行格数=365
# [INFO] 【目标面】best_score=0.0061，次优_score=0.0063，Δ=0.0002
# [INFO] 【目标面】best_score=0.0061，次优_score=0.0063，Δ=0.0002
# [INFO] 【漂移判级】PSI=0.0258，TV=0.0722，PosRateΔ=0.0019，等级=NONE，动作=无
# [INFO] 【漂移判级】PSI=0.0258，TV=0.0722，PosRateΔ=0.0019，等级=NONE，动作=无
# [INFO] 【重选后】α*=0.850，β*=0.090，EMA后=α=0.850/β=0.090，Δα=0.020，Δβ=0.040，ema=0.600，step_cap={'alpha':0.080,'beta':0.080}，BND占比=0.347，目标=0.0061(expected_cost)
# [INFO] 【重选后】α*=0.850，β*=0.090，EMA后=α=0.850/β=0.090，Δα=0.020，Δβ=0.040，ema=0.600，step_cap={'alpha':0.080,'beta':0.080}，BND占比=0.347，目标=0.0061(expected_cost)
# [INFO] 【增量】解锁标签月=2.11；合入季节桶=26；keep_history_ratio=0.30/容量=12；类均衡(POS/NEG)=9924/63540
# [INFO] 【增量】解锁标签月=2.11；合入季节桶=26；keep_history_ratio=0.30/容量=12；类均衡(POS/NEG)=9924/63540
# [INFO] 【参考库】year-month=2.12；同月历史窗口=0.12、1.12（年份=1987、1988，样本=5712）；邻近窗口=2.09、2.10、2.11（样本=8460）；历史仅用于构建Γ/Ψ候选，不混入当月评估
# [INFO] 【参考库】year-month=2.12；同月历史窗口=0.12、1.12（年份=1987、1988，样本=5712）；邻近窗口=2.09、2.10、2.11（样本=8460）；历史仅用于构建Γ/Ψ候选，不混入当月评估
# [INFO] 【数据切片】win=27(2.12) 样本数=2751，Month=12，Year_synth=1989
# [INFO] 【数据切片】win=27(2.12) 样本数=2751，Month=12，Year_synth=1989
# [INFO] 【示范库】Γ数=732，Ψ数=7905，历史同月来源窗口=0.12、1.12
# [INFO] 【示范库】Γ数=732，Ψ数=7905，历史同月来源窗口=0.12、1.12
# [INFO] 【相关度摘要】mean(E_pos)=0.0009，mean(E_neg)=0.0009，corr_diff=-0.0000
# [INFO] 【相关度摘要】mean(E_pos)=0.0009，mean(E_neg)=0.0009，corr_diff=-0.0000
# [INFO] 【三域概率摘要】mean(p_pos)=0.2293，mean(p_bnd)=0.0779，mean(p_neg)=0.6928
# [INFO] 【三域概率摘要】mean(p_pos)=0.2293，mean(p_bnd)=0.0779，mean(p_neg)=0.6928
# [INFO] 【网格信息】alpha网格=[0.55,0.90,0.02]，beta网格=[0.05,0.45,0.02]，可行格数=377
# [INFO] 【网格信息】alpha网格=[0.55,0.90,0.02]，beta网格=[0.05,0.45,0.02]，可行格数=377
# [INFO] 【目标面】best_score=0.0035，次优_score=0.0037，Δ=0.0002
# [INFO] 【目标面】best_score=0.0035，次优_score=0.0037，Δ=0.0002
# [INFO] 【漂移判级】PSI=0.0408，TV=0.0851，PosRateΔ=0.0648，等级=S1，动作=调σ
# [INFO] 【漂移判级】PSI=0.0408，TV=0.0851，PosRateΔ=0.0648，等级=S1，动作=调σ
# [INFO] 【重选后】α*=0.870，β*=0.050，EMA后=α=0.862/β=0.066，Δα=0.012，Δβ=0.024，ema=0.600，step_cap={'alpha':0.080,'beta':0.080}，BND占比=0.328，目标=0.0043(expected_cost)
# [INFO] 【重选后】α*=0.870，β*=0.050，EMA后=α=0.862/β=0.066，Δα=0.012，Δβ=0.024，ema=0.600，step_cap={'alpha':0.080,'beta':0.080}，BND占比=0.328，目标=0.0043(expected_cost)
# [INFO] 【增量】解锁标签月=2.12；合入季节桶=27；keep_history_ratio=0.30/容量=12；类均衡(POS/NEG)=10498/65717
# [INFO] 【增量】解锁标签月=2.12；合入季节桶=27；keep_history_ratio=0.30/容量=12；类均衡(POS/NEG)=10498/65717
# [INFO] 【参考库】year-month=3.01；同月历史窗口=1.01、2.01（年份=1988、1989，样本=5662）；邻近窗口=2.10、2.11、2.12（样本=8393）；历史仅用于构建Γ/Ψ候选，不混入当月评估
# [INFO] 【参考库】year-month=3.01；同月历史窗口=1.01、2.01（年份=1988、1989，样本=5662）；邻近窗口=2.10、2.11、2.12（样本=8393）；历史仅用于构建Γ/Ψ候选，不混入当月评估
# [INFO] 【数据切片】win=28(3.01) 样本数=2908，Month=01，Year_synth=1990
# [INFO] 【数据切片】win=28(3.01) 样本数=2908，Month=01，Year_synth=1990
# [INFO] 【示范库】Γ数=740，Ψ数=7860，历史同月来源窗口=1.01、2.01
# [INFO] 【示范库】Γ数=740，Ψ数=7860，历史同月来源窗口=1.01、2.01
# [INFO] 【相关度摘要】mean(E_pos)=0.0010，mean(E_neg)=0.0009，corr_diff=0.0001
# [INFO] 【相关度摘要】mean(E_pos)=0.0010，mean(E_neg)=0.0009，corr_diff=0.0001
# [INFO] 【三域概率摘要】mean(p_pos)=0.2339，mean(p_bnd)=0.0705，mean(p_neg)=0.6956
# [INFO] 【三域概率摘要】mean(p_pos)=0.2339，mean(p_bnd)=0.0705，mean(p_neg)=0.6956
# [INFO] 【网格信息】alpha网格=[0.55,0.90,0.02]，beta网格=[0.05,0.45,0.02]，可行格数=378
# [INFO] 【网格信息】alpha网格=[0.55,0.90,0.02]，beta网格=[0.05,0.45,0.02]，可行格数=378
# [INFO] 【目标面】best_score=0.0031，次优_score=0.0037，Δ=0.0006
# [INFO] 【目标面】best_score=0.0031，次优_score=0.0037，Δ=0.0006
# [INFO] 【漂移判级】PSI=0.0074，TV=0.0354，PosRateΔ=0.0002，等级=NONE，动作=无
# [INFO] 【漂移判级】PSI=0.0074，TV=0.0354，PosRateΔ=0.0002，等级=NONE，动作=无
# [INFO] 【重选后】α*=0.890，β*=0.050，EMA后=α=0.879/β=0.056，Δα=0.017，Δβ=0.010，ema=0.600，step_cap={'alpha':0.080,'beta':0.080}，BND占比=0.329，目标=0.0035(expected_cost)
# [INFO] 【重选后】α*=0.890，β*=0.050，EMA后=α=0.879/β=0.056，Δα=0.017，Δβ=0.010，ema=0.600，step_cap={'alpha':0.080,'beta':0.080}，BND占比=0.329，目标=0.0035(expected_cost)
# [INFO] 【增量】解锁标签月=3.01；合入季节桶=28；keep_history_ratio=0.30/容量=12；类均衡(POS/NEG)=10916/68207
# [INFO] 【增量】解锁标签月=3.01；合入季节桶=28；keep_history_ratio=0.30/容量=12；类均衡(POS/NEG)=10916/68207
# [INFO] 【参考库】year-month=3.02；同月历史窗口=1.02、2.02（年份=1988、1989，样本=5221）；邻近窗口=2.11、2.12、3.01（样本=8430）；历史仅用于构建Γ/Ψ候选，不混入当月评估
# [INFO] 【参考库】year-month=3.02；同月历史窗口=1.02、2.02（年份=1988、1989，样本=5221）；邻近窗口=2.11、2.12、3.01（样本=8430）；历史仅用于构建Γ/Ψ候选，不混入当月评估
# [INFO] 【数据切片】win=29(3.02) 样本数=2611，Month=02，Year_synth=1990
# [INFO] 【数据切片】win=29(3.02) 样本数=2611，Month=02，Year_synth=1990
# [INFO] 【示范库】Γ数=742，Ψ数=7564，历史同月来源窗口=1.02、2.02
# [INFO] 【示范库】Γ数=742，Ψ数=7564，历史同月来源窗口=1.02、2.02
# [INFO] 【相关度摘要】mean(E_pos)=0.0008，mean(E_neg)=0.0009，corr_diff=-0.0000
# [INFO] 【相关度摘要】mean(E_pos)=0.0008，mean(E_neg)=0.0009，corr_diff=-0.0000
# [INFO] 【三域概率摘要】mean(p_pos)=0.2388，mean(p_bnd)=0.0727，mean(p_neg)=0.6885
# [INFO] 【三域概率摘要】mean(p_pos)=0.2388，mean(p_bnd)=0.0727，mean(p_neg)=0.6885
# [INFO] 【网格信息】alpha网格=[0.55,0.90,0.02]，beta网格=[0.05,0.45,0.02]，可行格数=376
# [INFO] 【网格信息】alpha网格=[0.55,0.90,0.02]，beta网格=[0.05,0.45,0.02]，可行格数=376
# [INFO] 【目标面】best_score=0.0037，次优_score=0.0039，Δ=0.0001
# [INFO] 【目标面】best_score=0.0037，次优_score=0.0039，Δ=0.0001
# [INFO] 【漂移判级】PSI=0.0103，TV=0.0442，PosRateΔ=0.0380，等级=NONE，动作=无
# [INFO] 【漂移判级】PSI=0.0103，TV=0.0442，PosRateΔ=0.0380，等级=NONE，动作=无
# [INFO] 【重选后】α*=0.890，β*=0.070，EMA后=α=0.886/β=0.065，Δα=0.007，Δβ=0.008，ema=0.600，step_cap={'alpha':0.080,'beta':0.080}，BND占比=0.347，目标=0.0036(expected_cost)
# [INFO] 【重选后】α*=0.890，β*=0.070，EMA后=α=0.886/β=0.065，Δα=0.007，Δβ=0.008，ema=0.600，step_cap={'alpha':0.080,'beta':0.080}，BND占比=0.347，目标=0.0036(expected_cost)
# [INFO] 【增量】解锁标签月=3.02；合入季节桶=29；keep_history_ratio=0.30/容量=12；类均衡(POS/NEG)=11391/70343
# [INFO] 【增量】解锁标签月=3.02；合入季节桶=29；keep_history_ratio=0.30/容量=12；类均衡(POS/NEG)=11391/70343
# [INFO] 【参考库】year-month=3.03；同月历史窗口=1.03、2.03（年份=1988、1989，样本=5766）；邻近窗口=2.12、3.01、3.02（样本=8270）；历史仅用于构建Γ/Ψ候选，不混入当月评估
# [INFO] 【参考库】year-month=3.03；同月历史窗口=1.03、2.03（年份=1988、1989，样本=5766）；邻近窗口=2.12、3.01、3.02（样本=8270）；历史仅用于构建Γ/Ψ候选，不混入当月评估
# [INFO] 【数据切片】win=30(3.03) 样本数=3025，Month=03，Year_synth=1990
# [INFO] 【数据切片】win=30(3.03) 样本数=3025，Month=03，Year_synth=1990
# [INFO] 【示范库】Γ数=770，Ψ数=7688，历史同月来源窗口=1.03、2.03
# [INFO] 【示范库】Γ数=770，Ψ数=7688，历史同月来源窗口=1.03、2.03
# [INFO] 【相关度摘要】mean(E_pos)=0.0011，mean(E_neg)=0.0009，corr_diff=0.0002
# [INFO] 【相关度摘要】mean(E_pos)=0.0011，mean(E_neg)=0.0009，corr_diff=0.0002
# [INFO] 【三域概率摘要】mean(p_pos)=0.2426，mean(p_bnd)=0.0807，mean(p_neg)=0.6766
# [INFO] 【三域概率摘要】mean(p_pos)=0.2426，mean(p_bnd)=0.0807，mean(p_neg)=0.6766
# [INFO] 【网格信息】alpha网格=[0.55,0.90,0.02]，beta网格=[0.05,0.45,0.02]，可行格数=375
# [INFO] 【网格信息】alpha网格=[0.55,0.90,0.02]，beta网格=[0.05,0.45,0.02]，可行格数=375
# [INFO] 【目标面】best_score=0.0040，次优_score=0.0041，Δ=0.0000
# [INFO] 【目标面】best_score=0.0040，次优_score=0.0041，Δ=0.0000
# [INFO] 【漂移判级】PSI=0.0133，TV=0.0508，PosRateΔ=0.0118，等级=NONE，动作=无
# [INFO] 【漂移判级】PSI=0.0133，TV=0.0508，PosRateΔ=0.0118，等级=NONE，动作=无
# [INFO] 【重选后】α*=0.870，β*=0.070，EMA后=α=0.846/β=0.050，Δα=0.040，Δβ=0.015，ema=0.600，step_cap={'alpha':0.080,'beta':0.080}，BND占比=0.348，目标=0.0041(expected_cost)
# [INFO] 【重选后】α*=0.870，β*=0.070，EMA后=α=0.846/β=0.050，Δα=0.040，Δβ=0.015，ema=0.600，step_cap={'alpha':0.080,'beta':0.080}，BND占比=0.348，目标=0.0041(expected_cost)
# [INFO] 【增量】解锁标签月=3.03；合入季节桶=30；keep_history_ratio=0.30/容量=12；类均衡(POS/NEG)=11862/72897
# [INFO] 【增量】解锁标签月=3.03；合入季节桶=30；keep_history_ratio=0.30/容量=12；类均衡(POS/NEG)=11862/72897
# [INFO] 【参考库】year-month=3.04；同月历史窗口=1.04、2.04（年份=1988、1989，样本=5387）；邻近窗口=3.01、3.02、3.03（样本=8544）；历史仅用于构建Γ/Ψ候选，不混入当月评估
# [INFO] 【参考库】year-month=3.04；同月历史窗口=1.04、2.04（年份=1988、1989，样本=5387）；邻近窗口=3.01、3.02、3.03（样本=8544）；历史仅用于构建Γ/Ψ候选，不混入当月评估
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 5
#       2 from s3wdlib.v02_flow import run_streaming_flow
#       4 print("\n【步骤2】开始运行流式前滚 v02（只保留动态部分）...")
# ----> 5 results = run_streaming_flow(str(CONFIG_PATH))
#       7 trace_df = results.get("threshold_trace")
#       8 metrics_df = results.get("window_metrics")
#
# File e:\yan\组\三支决策\机器学习\C三支决策与不平衡数据集分类\S3WD实验\s3wdlib\v02_flow.py:914, in run_streaming_flow(cfg_path, warmup_windows)
#     891     stats = {
#     892         "P_block": P_block,
#     893         "alpha_star": alpha_star,
#    (...)
#     910         "beta_cap": beta_cap,
#     911     }
#     912     return positive, boundary, stats
# --> 914 _, _, stats = _recompute(float(runtime_state.get("sigma", 0.5)))
#     916 psi_val, tv_val = _calc_distribution_metrics(
#     917     baseline_info["p_pos"], stats["P_block"]["p_pos"], baseline_info["bins"]
#     918 )
#     919 posrate_curr = float(y_block.mean())
#
# File e:\yan\组\三支决策\机器学习\C三支决策与不平衡数据集分类\S3WD实验\s3wdlib\v02_flow.py:783, in run_streaming_flow.<locals>._recompute(sigma_value)
#     781 runtime_state["sigma"] = sigma_value
#     782 similarity_configure({"sigma": sigma_value})
# --> 783 E_pos, E_neg = _compute_similarity_block(
#     784     X_block,
#     785     buckets_block,
#     786     ref_tuples,
#     787     sigma=sigma_value,
#     788     sim_params=runtime_state,
#     789 )
#     790 P_block = to_trisect_probs(E_pos, E_neg)
#     791 alpha_star, beta_star, grid_info = select_alpha_beta(
#     792     P_block,
#     793     measure_grid,
#    (...)
#     797     beta_weight=beta_weight,
#     798 )
#
# File e:\yan\组\三支决策\机器学习\C三支决策与不平衡数据集分类\S3WD实验\s3wdlib\v02_flow.py:309, in _compute_similarity_block(X_block, bucket_ids, ref_map, sigma, sim_params)
#     300         E_pos[positions] = corr_to_set(
#     301             subset,
#     302             refs["pos"],
#    (...)
#     306             mix_alpha=mix_alpha,
#     307         )
#     308     if refs.get("neg"):
# --> 309         E_neg[positions] = corr_to_set(
#     310             subset,
#     311             refs["neg"],
#     312             sigma,
#     313             cat_weights,
#     314             combine=combine,
#     315             mix_alpha=mix_alpha,
#     316         )
#     317 return E_pos, E_neg
#
# File e:\yan\组\三支决策\机器学习\C三支决策与不平衡数据集分类\S3WD实验\s3wdlib\similarity.py:148, in corr_to_set(X_block, ref_set, sigma, cat_weights, combine, mix_alpha)
#     146 for item in ref_set:
#     147     for pos, row in enumerate(records):
# --> 148         sim = mixed_similarity(row, item, sigma=sigma, cat_weights=cat_weights, combine=combine, mix_alpha=mix_alpha)
#     149         sims[pos] += sim * float(item.weight)
#     150         weight_sum[pos] += float(item.weight)
#
# File e:\yan\组\三支决策\机器学习\C三支决策与不平衡数据集分类\S3WD实验\s3wdlib\similarity.py:99, in mixed_similarity(x_row, tau_item, sigma, cat_weights, combine, mix_alpha)
#      96     x_num = x_arr
#      97     x_cat = {}
# ---> 99 num_sim = rbf_num_sim(x_num, tau_item.num_vec, sigma)
#     100 cat_sim = cat_match(x_cat, tau_item.cat_fields, cat_weights)
#     102 strategy = str(combine).lower()
#
# File e:\yan\组\三支决策\机器学习\C三支决策与不平衡数据集分类\S3WD实验\s3wdlib\similarity.py:58, in rbf_num_sim(x_num, tau_num, sigma)
#      56 sigma = max(float(sigma), 1e-6)
#      57 diff = x_num - tau_num
# ---> 58 dist2 = float(np.dot(diff, diff))
#      59 return float(np.exp(-dist2 / (2 * sigma ** 2)))
#
# KeyboardInterrupt:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
